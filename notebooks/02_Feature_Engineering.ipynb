# %%
# Step 1: Environment Setup and Basic Download Test

# Install necessary libraries quietly
# !pip install vitaldb matplotlib awscli xgboost scikit-learn --quiet

import os
import vitaldb

# Define a temporary directory for a single test file
TEST_DIR = 'temp_test_vital_file'
os.makedirs(TEST_DIR, exist_ok=True)

# Define the path for a single test file (e.g., 0001.vital)
TEST_CASE_ID = 1
TEST_FILENAME = f'{TEST_CASE_ID:04d}.vital'
TEST_FILE_PATH = os.path.join(TEST_DIR, TEST_FILENAME)
S3_SOURCE_PATH = f's3://physionet-open/vitaldb/1.0.0/vital_files/{TEST_FILENAME}'

print(f"Attempting to download {TEST_FILENAME} to {TEST_FILE_PATH}...")

# Remove existing file to ensure a fresh download
if os.path.exists(TEST_FILE_PATH):
    os.remove(TEST_FILE_PATH)
    print(f"Removed existing {TEST_FILENAME}.")

# Download the file
download_command = f'aws s3 cp --no-sign-request {S3_SOURCE_PATH} {TEST_FILE_PATH}'
os.system(download_command)

# Verify download
if os.path.exists(TEST_FILE_PATH):
    print(f"SUCCESS: {TEST_FILENAME} downloaded successfully.")
    # Optional: Try to open it with vitaldb to confirm it's valid
    try:
        vf = vitaldb.VitalFile(TEST_FILE_PATH)
        print(f"SUCCESS: {TEST_FILENAME} can be opened by vitaldb. It has {len(vf.get_track_names())} tracks.")
    except Exception as e:
        print(f"WARNING: Could not open {TEST_FILENAME} with vitaldb: {e}")
else:
    print(f"ERROR: {TEST_FILENAME} was NOT downloaded.")

# Clean up the test file and directory
if os.path.exists(TEST_FILE_PATH):
    os.remove(TEST_FILE_PATH)
    print(f"Cleaned up {TEST_FILENAME}.")
if os.path.exists(TEST_DIR):
    os.rmdir(TEST_DIR)
    print(f"Cleaned up directory {TEST_DIR}.")

print("\nStep 1 complete. Please review the output for success messages.")
# Out:
# Attempting to download 0001.vital to temp_test_vital_file/0001.vital...
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0001.vital to temp_test_vital_file/0001.vital
# SUCCESS: 0001.vital downloaded successfully.
# SUCCESS: 0001.vital can be opened by vitaldb. It has 79 tracks.
# Cleaned up 0001.vital.
# Cleaned up directory temp_test_vital_file.
#
# Step 1 complete. Please review the output for success messages.

# %%
# Step 2: Feature Engineering Logic Test (Single Patient)

import os
import vitaldb
import pandas as pd
import numpy as np

# --- Configuration Parameters (re-defined for this cell's context) ---
VITAL_FILES_LOCAL_DIR = 'temp_feature_test' # Temporary directory for this test
INPUT_VITALS = [
    'Solar8000/HR',
    'Solar8000/ART_MBP',
    'Solar8000/PLETH_SPO2',
    'Solar8000/ETCO2'
]
TARGET_VITAL = 'BIS/BIS'
TRACKS_FOR_MODEL = INPUT_VITALS + [TARGET_VITAL, 'EVENT']
ROLLING_WINDOW_SIZE = 300 # 5 minutes in seconds for feature engineering

# --- Helper Functions (from previous code) ---
def calculate_slope(y):
    """Calculates the slope of a series, handling NaNs."""
    y_clean = y.dropna()
    if len(y_clean) < 2:
        return np.nan
    return np.polyfit(np.arange(len(y_clean)), y_clean, 1)[0]

def generate_patient_features(case_ids: list, vital_files_dir: str, tracks_to_load: list,
                               window_size: int, input_vitals: list, target_vital: str):
    """
    Generator function to load patient data, engineer features, and yield processed DataFrames.
    (Simplified for single-patient test, but designed for iteration)
    """
    feature_cols_template = []
    for col in input_vitals:
        feature_cols_template.extend([
            f'{col}_mean', f'{col}_std', f'{col}_min', f'{col}_max', f'{col}_trend'
        ])

    for case_id in case_ids: # This loop will run only once for our test
        case_filename = f'{case_id:04d}.vital'
        file_path = os.path.join(vital_files_dir, case_filename)

        if not os.path.exists(file_path):
            print(f"Warning: File '{file_path}' not found for Case {case_id}. Skipping.")
            continue

        try:
            vf = vitaldb.VitalFile(file_path)
            df_raw = vf.to_pandas(tracks_to_load, interval=1)

            df_model = df_raw.copy()

            # Perform feature engineering
            for col in input_vitals:
                df_model[f'{col}_mean'] = df_model[col].rolling(window=window_size, min_periods=1).mean()
                df_model[f'{col}_std'] = df_model[col].rolling(window=window_size, min_periods=1).std()
                df_model[f'{col}_min'] = df_model[col].rolling(window=window_size, min_periods=1).min()
                df_model[f'{col}_max'] = df_model[col].rolling(window=window_size, min_periods=1).max()
                df_model[f'{col}_trend'] = df_model[col].rolling(window=window_size, min_periods=2).apply(calculate_slope, raw=False)

            feature_cols = [f for f in feature_cols_template if f in df_model.columns]
            final_cols = feature_cols + [target_vital]
            df_processed = df_model[final_cols].copy()

            # Drop rows where the target is NaN or where all features are NaN
            df_processed = df_processed.dropna(subset=[target_vital]).dropna(how='all', subset=feature_cols)

            if not df_processed.empty:
                yield df_processed
            else:
                print(f"No valid data points after feature engineering for Case {case_id}. Skipping.")

        except Exception as e:
            print(f"Error processing Case {case_id}: {e}. Skipping.")

# --- Test Execution for Step 2 ---
TEST_CASE_ID = 1
TEST_DIR = 'temp_feature_test'
TEST_FILENAME = f'{TEST_CASE_ID:04d}.vital'
TEST_FILE_PATH = os.path.join(TEST_DIR, TEST_FILENAME)
S3_SOURCE_PATH = f's3://physionet-open/vitaldb/1.0.0/vital_files/{TEST_FILENAME}'

# Ensure directory exists and download the test file
os.makedirs(TEST_DIR, exist_ok=True)
if not os.path.exists(TEST_FILE_PATH):
    download_command = f'aws s3 cp --no-sign-request {S3_SOURCE_PATH} {TEST_FILE_PATH}'
    os.system(download_command)
    print(f"Downloaded {TEST_FILENAME} for feature engineering test.")
else:
    print(f"Using existing {TEST_FILENAME} for feature engineering test.")

# Generate features for the single test case
print(f"\nGenerating features for Case {TEST_CASE_ID}...")
processed_dfs = list(generate_patient_features(
    [TEST_CASE_ID], TEST_DIR, TRACKS_FOR_MODEL, ROLLING_WINDOW_SIZE, INPUT_VITALS, TARGET_VITAL
))

if processed_dfs:
    test_df = processed_dfs[0]
    print(f"\nSUCCESS: Processed DataFrame shape: {test_df.shape}")
    print("First 5 rows of processed data:")
    print(test_df.head())
    print("\nLast 5 rows of processed data:")
    print(test_df.tail()) # Check tail to see if NaNs at start are handled
else:
    print(f"ERROR: No data generated for Case {TEST_CASE_ID} after feature engineering.")

# Clean up the test file and directory
if os.path.exists(TEST_FILE_PATH):
    os.remove(TEST_FILE_PATH)
    print(f"Cleaned up {TEST_FILENAME}.")
if os.path.exists(TEST_DIR):
    os.rmdir(TEST_DIR)
    print(f"Cleaned up directory {TEST_DIR}.")

print("\nStep 2 complete. Please review the output for the DataFrame shape and head/tail.")
# Out:
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0001.vital to temp_feature_test/0001.vital
# Downloaded 0001.vital for feature engineering test.
#
# Generating features for Case 1...
#
# SUCCESS: Processed DataFrame shape: (11423, 21)
# First 5 rows of processed data:
#    Solar8000/HR_mean  Solar8000/HR_std  Solar8000/HR_min  Solar8000/HR_max  \
# 2          88.000000               NaN              88.0              88.0
# 3          88.000000               NaN              88.0              88.0
# 4          87.500000          0.707107              87.0              88.0
# 5          87.500000          0.707107              87.0              88.0
# 6          87.666667          0.577350              87.0              88.0
#
#    Solar8000/HR_trend  Solar8000/ART_MBP_mean  Solar8000/ART_MBP_std  \
# 2                 NaN                    -8.0                    NaN
# 3                 NaN                    -8.0                    NaN
# 4       -1.000000e+00                    -8.0                    0.0
# 5       -1.000000e+00                    -8.0                    0.0
# 6       -6.355287e-15                    -8.0                    0.0
#
#    Solar8000/ART_MBP_min  Solar8000/ART_MBP_max  Solar8000/ART_MBP_trend  ...  \
# 2                   -8.0                   -8.0                      NaN  ...
# 3                   -8.0                   -8.0                      NaN  ...
# 4                   -8.0                   -8.0             8.881784e-16  ...
# 5                   -8.0                   -8.0             8.881784e-16  ...
# 6                   -8.0                   -8.0             7.944109e-16  ...
#
#    Solar8000/PLETH_SPO2_std  Solar8000/PLETH_SPO2_min  \
# 2                       NaN                      96.0
# 3                       NaN                      96.0
# 4                   0.00000                      96.0
# 5                   0.00000                      96.0
# 6                   0.57735                      96.0
#
#    Solar8000/PLETH_SPO2_max  Solar8000/PLETH_SPO2_trend  Solar8000/ETCO2_mean  \
# 2                      96.0                         NaN                   NaN
# 3                      96.0                         NaN                   NaN
# 4                      96.0               -1.421085e-14                   NaN
# 5                      96.0               -1.421085e-14                   NaN
# 6                      97.0                5.000000e-01                   NaN
#
#    Solar8000/ETCO2_std  Solar8000/ETCO2_min  Solar8000/ETCO2_max  \
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
# 5                  NaN                  NaN                  NaN
# 6                  NaN                  NaN                  NaN
#
#    Solar8000/ETCO2_trend  BIS/BIS
# 2                    NaN      0.0
# 3                    NaN      0.0
# 4                    NaN      0.0
# 5                    NaN      0.0
# 6                    NaN      0.0
#
# [5 rows x 21 columns]
#
# Last 5 rows of processed data:
#        Solar8000/HR_mean  Solar8000/HR_std  Solar8000/HR_min  \
# 11536                NaN               NaN               NaN
# 11537                NaN               NaN               NaN
# 11538                NaN               NaN               NaN
# 11539                NaN               NaN               NaN
# 11540                NaN               NaN               NaN
#
#        Solar8000/HR_max  Solar8000/HR_trend  Solar8000/ART_MBP_mean  \
# 11536               NaN                 NaN                     NaN
# 11537               NaN                 NaN                     NaN
# 11538               NaN                 NaN                     NaN
# 11539               NaN                 NaN                     NaN
# 11540               NaN                 NaN                     NaN
#
#        Solar8000/ART_MBP_std  Solar8000/ART_MBP_min  Solar8000/ART_MBP_max  \
# 11536                    NaN                    NaN                    NaN
# 11537                    NaN                    NaN                    NaN
# 11538                    NaN                    NaN                    NaN
# 11539                    NaN                    NaN                    NaN
# 11540                    NaN                    NaN                    NaN
#
#        Solar8000/ART_MBP_trend  ...  Solar8000/PLETH_SPO2_std  \
# 11536                      NaN  ...                       NaN
# 11537                      NaN  ...                       NaN
# 11538                      NaN  ...                       NaN
# 11539                      NaN  ...                       NaN
# 11540                      NaN  ...                       NaN
#
#        Solar8000/PLETH_SPO2_min  Solar8000/PLETH_SPO2_max  \
# 11536                      80.0                      80.0
# 11537                      80.0                      80.0
# 11538                      80.0                      80.0
# 11539                      80.0                      80.0
# 11540                      80.0                      80.0
#
#        Solar8000/PLETH_SPO2_trend  Solar8000/ETCO2_mean  Solar8000/ETCO2_std  \
# 11536                         NaN                   NaN                  NaN
# 11537                         NaN                   NaN                  NaN
# 11538                         NaN                   NaN                  NaN
# 11539                         NaN                   NaN                  NaN
# 11540                         NaN                   NaN                  NaN
#
#        Solar8000/ETCO2_min  Solar8000/ETCO2_max  Solar8000/ETCO2_trend  \
# 11536                  NaN                  NaN                    NaN
# 11537                  NaN                  NaN                    NaN
# 11538                  NaN                  NaN                    NaN
# 11539                  NaN                  NaN                    NaN
# 11540                  NaN                  NaN                    NaN
#
#        BIS/BIS
# 11536      0.0
# 11537      0.0
# 11538      0.0
# 11539      0.0
# 11540      0.0
#
# [5 rows x 21 columns]
# Cleaned up 0001.vital.
# Cleaned up directory temp_feature_test.
#
# Step 2 complete. Please review the output for the DataFrame shape and head/tail.
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()

# %%
# Step 3: XGBoost Training with Monitoring (Small Scale)

import os
import vitaldb
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
import matplotlib.pyplot as plt

# --- Configuration Parameters (re-defined for this cell's context) ---
VITAL_FILES_LOCAL_DIR = 'vital_files_full_dataset_1000' # Directory where files are downloaded
MODEL_SAVE_PATH = 'vitaldb_bis_model_test.json' # Path to save the trained model (test version)

INPUT_VITALS = [
    'Solar8000/HR',
    'Solar8000/ART_MBP',
    'Solar8000/PLETH_SPO2',
    'Solar8000/ETCO2'
]
TARGET_VITAL = 'BIS/BIS'
TRACKS_FOR_MODEL = INPUT_VITALS + [TARGET_VITAL, 'EVENT']
ROLLING_WINDOW_SIZE = 300 # 5 minutes in seconds for feature engineering
TRAIN_TEST_SPLIT_RATIO = 0.8 # 80% for training, 20% for validation
RANDOM_SEED = 42 # For reproducibility

NUM_PATIENTS_TO_PROCESS = 10 # Limit to 10 patients for this test run

# --- Helper Functions (from previous code) ---
def calculate_slope(y):
    """Calculates the slope of a series, handling NaNs."""
    y_clean = y.dropna()
    if len(y_clean) < 2:
        return np.nan
    return np.polyfit(np.arange(len(y_clean)), y_clean, 1)[0]

def generate_patient_features(case_ids: list, vital_files_dir: str, tracks_to_load: list,
                               window_size: int, input_vitals: list, target_vital: str):
    """
    Generator function to load patient data, engineer features, and yield processed DataFrames.
    """
    feature_cols_template = []
    for col in input_vitals:
        feature_cols_template.extend([
            f'{col}_mean', f'{col}_std', f'{col}_min', f'{col}_max', f'{col}_trend'
        ])

    for i, case_id in enumerate(case_ids):
        case_filename = f'{case_id:04d}.vital'
        file_path = os.path.join(vital_files_dir, case_filename)

        if not os.path.exists(file_path):
            # This warning is expected if you haven't run the full download for 1000 files yet
            # For this test, ensure the first 10 files are present from Step 1's download logic
            print(f"Warning: File '{file_path}' not found for Case {case_id}. Skipping.")
            continue

        try:
            vf = vitaldb.VitalFile(file_path)
            df_raw = vf.to_pandas(tracks_to_load, interval=1)

            df_model = df_raw.copy()

            for col in input_vitals:
                df_model[f'{col}_mean'] = df_model[col].rolling(window=window_size, min_periods=1).mean()
                df_model[f'{col}_std'] = df_model[col].rolling(window=window_size, min_periods=1).std()
                df_model[f'{col}_min'] = df_model[col].rolling(window=window_size, min_periods=1).min()
                df_model[f'{col}_max'] = df_model[col].rolling(window=window_size, min_periods=1).max()
                df_model[f'{col}_trend'] = df_model[col].rolling(window=window_size, min_periods=2).apply(calculate_slope, raw=False)

            feature_cols = [f for f in feature_cols_template if f in df_model.columns]
            final_cols = feature_cols + [target_vital]
            df_processed = df_model[final_cols].copy()

            df_processed = df_processed.dropna(subset=[target_vital]).dropna(how='all', subset=feature_cols)

            if not df_processed.empty:
                yield df_processed
            else:
                print(f"No valid data points after feature engineering for Case {case_id}. Skipping.")

        except Exception as e:
            print(f"Error processing Case {case_id}: {e}. Skipping.")

# --- Test Execution for Step 3 ---
print(f"--- Step 3: XGBoost Training Test (First {NUM_PATIENTS_TO_PROCESS} Patients) ---")

# Ensure the directory for downloaded files exists (from previous steps)
os.makedirs(VITAL_FILES_LOCAL_DIR, exist_ok=True)

# Use only the first NUM_PATIENTS_TO_PROCESS for training
all_case_ids = list(range(1, NUM_PATIENTS_TO_PROCESS + 1))

# Split case IDs into training and validation sets (patient-level split)
train_case_ids, val_case_ids = train_test_split(
    all_case_ids, test_size=(1 - TRAIN_TEST_SPLIT_RATIO), random_state=RANDOM_SEED
)

print(f"Total cases for training/validation: {len(all_case_ids)}")
print(f"Training cases (randomly selected patient IDs): {len(train_case_ids)}")
print(f"Validation cases (randomly selected patient IDs): {len(val_case_ids)}")

# Collect training data with progress updates
print("\nCollecting training data...")
X_train_list = []
y_train_list = []
for i, df_patient in enumerate(generate_patient_features(train_case_ids, VITAL_FILES_LOCAL_DIR, TRACKS_FOR_MODEL,
                                            ROLLING_WINDOW_SIZE, INPUT_VITALS, TARGET_VITAL)):
    X_train_list.append(df_patient.drop(columns=[TARGET_VITAL]))
    y_train_list.append(df_patient[TARGET_VITAL])
    if (i + 1) % 2 == 0 or (i + 1) == len(train_case_ids): # Update more frequently for 10 patients
        print(f"  Processed {i+1}/{len(train_case_ids)} training patients. Current data points: {sum(len(x) for x in X_train_list)}")

if not X_train_list:
    print("No training data collected. Cannot proceed with training.")
    exit()

X_train = pd.concat(X_train_list, ignore_index=True)
y_train = pd.concat(y_train_list, ignore_index=True)
print(f"Training data shape: X={X_train.shape}, y={y_train.shape}")

# Collect validation data with progress updates
print("\nCollecting validation data...")
X_val_list = []
y_val_list = []
for i, df_patient in enumerate(generate_patient_features(val_case_ids, VITAL_FILES_LOCAL_DIR, TRACKS_FOR_MODEL,
                                            ROLLING_WINDOW_SIZE, INPUT_VITALS, TARGET_VITAL)):
    X_val_list.append(df_patient.drop(columns=[TARGET_VITAL]))
    y_val_list.append(df_patient[TARGET_VITAL])
    if (i + 1) % 1 == 0 or (i + 1) == len(val_case_ids): # Update for every validation patient
        print(f"  Processed {i+1}/{len(val_case_ids)} validation patients. Current data points: {sum(len(x) for x in X_val_list)}")

if not X_val_list:
    print("No validation data collected. Cannot evaluate model.")
    X_val = pd.DataFrame()
    y_val = pd.Series()
else:
    X_val = pd.concat(X_val_list, ignore_index=True)
    y_val = pd.concat(y_val_list, ignore_index=True)
    print(f"Validation data shape: X={X_val.shape}, y={y_val.shape}")


print("\nTraining XGBoost Regressor model with validation monitoring...")
model = XGBRegressor(
    objective='reg:squarederror',
    n_estimators=100,             # Reduced estimators for faster test
    learning_rate=0.1,
    max_depth=5,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=RANDOM_SEED,
    n_jobs=-1,
    tree_method='hist'
)

# The correct way to monitor training progress in recent XGBoost versions
# is by passing eval_set and eval_metric to fit, and setting verbose to True
# or an integer for periodic output.
model.fit(X_train, y_train,
          eval_set=[(X_train, y_train), (X_val, y_val)],
          eval_metric='rmse', # Root Mean Squared Error
          verbose=True, # Set to True to see evaluation metrics during training
          early_stopping_rounds=10 # Stop if validation RMSE doesn't improve for 10 rounds (reduced for faster test)
         )
print("Model training complete.")

# Save the trained model
model.save_model(MODEL_SAVE_PATH)
print(f"Model saved to {MODEL_SAVE_PATH}")

# Evaluate the model
if not X_val.empty:
    print("\nFinal model evaluation on validation set...")
    y_pred = model.predict(X_val)

    mae = mean_absolute_error(y_val, y_pred)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    r2 = r2_score(y_val, y_pred)

    print(f"Validation MAE: {mae:.2f}")
    print(f"Validation RMSE: {rmse:.2f}")
    print(f"Validation R-squared: {r2:.2f}")

    # Plotting predictions vs actual for a subset
    plt.figure(figsize=(10, 6))
    plt.scatter(y_val, y_pred, alpha=0.3)
    # Plot a perfect prediction line
    min_val = min(y_val.min(), y_pred.min())
    max_val = max(y_val.max(), y_pred.max())
    plt.plot([min_val, max_val], [min_val, max_val], 'r--', lw=2)
    plt.xlabel("Actual BIS Score")
    plt.ylabel("Predicted BIS Score")
    plt.title("Actual vs. Predicted BIS Score (Validation Set)")
    plt.grid(True)
    plt.show()
else:
    print("Skipping final model evaluation as no validation data was collected.")

print("\nStep 3 complete. Please review the output for training progress and evaluation metrics.")
# Out:
# --- Step 3: XGBoost Training Test (First 10 Patients) ---
# Total cases for training/validation: 10
# Training cases (randomly selected patient IDs): 8
# Validation cases (randomly selected patient IDs): 2
#
# Collecting training data...
#   Processed 2/8 training patients. Current data points: 14903
#   Processed 4/8 training patients. Current data points: 25190
#   Processed 6/8 training patients. Current data points: 67675
#   Processed 8/8 training patients. Current data points: 95465
# Training data shape: X=(95465, 20), y=(95465,)
#
# Collecting validation data...
#   Processed 1/2 validation patients. Current data points: 4276
#   Processed 2/2 validation patients. Current data points: 19886
# Validation data shape: X=(19886, 20), y=(19886,)
#
# Training XGBoost Regressor model with validation monitoring...
# [0]	validation_0-rmse:15.14592	validation_1-rmse:17.09682
# [1]	validation_0-rmse:14.53507	validation_1-rmse:17.09645
# [2]	validation_0-rmse:14.01511	validation_1-rmse:16.82562
# [3]	validation_0-rmse:13.53296	validation_1-rmse:16.77956
# [4]	validation_0-rmse:13.16312	validation_1-rmse:16.82365
# [5]	validation_0-rmse:12.75658	validation_1-rmse:16.98458
# [6]	validation_0-rmse:12.42122	validation_1-rmse:16.90493
# [7]	validation_0-rmse:12.09362	validation_1-rmse:16.84991
# [8]	validation_0-rmse:11.80377	validation_1-rmse:16.77457
# [9]	validation_0-rmse:11.54309	validation_1-rmse:16.79012
# [10]	validation_0-rmse:11.26714	validation_1-rmse:16.88618
# /usr/local/lib/python3.11/dist-packages/xgboost/sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [11]	validation_0-rmse:11.04138	validation_1-rmse:17.01418
# [12]	validation_0-rmse:10.85910	validation_1-rmse:16.86267
# [13]	validation_0-rmse:10.62229	validation_1-rmse:17.00900
# [14]	validation_0-rmse:10.41263	validation_1-rmse:17.09042
# [15]	validation_0-rmse:10.26175	validation_1-rmse:17.23388
# [16]	validation_0-rmse:10.11583	validation_1-rmse:17.24813
# [17]	validation_0-rmse:9.89264	validation_1-rmse:17.24580
# [18]	validation_0-rmse:9.75178	validation_1-rmse:17.16370
# Model training complete.
# Model saved to vitaldb_bis_model_test.json
#
# Final model evaluation on validation set...
# Validation MAE: 11.60
# Validation RMSE: 16.77
# Validation R-squared: -0.06
# Step 3 complete. Please review the output for training progress and evaluation metrics.

# %%
# !pip install vitaldb matplotlib awscli xgboost scikit-learn --quiet


# Step 4: XGBoost Training with Monitoring (Increased Scale & Warning Fix)

import os
import vitaldb
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
import matplotlib.pyplot as plt

# --- Configuration Parameters ---
VITAL_FILES_LOCAL_DIR = 'vital_files_full_dataset_1000' # Directory where files are downloaded
MODEL_SAVE_PATH = 'vitaldb_bis_model_test_100_patients.json' # Path to save the trained model (for 100 patients)

INPUT_VITALS = [
    'Solar8000/HR',
    'Solar8000/ART_MBP',
    'Solar8000/PLETH_SPO2',
    'Solar8000/ETCO2'
]
TARGET_VITAL = 'BIS/BIS'
TRACKS_FOR_MODEL = INPUT_VITALS + [TARGET_VITAL, 'EVENT']
ROLLING_WINDOW_SIZE = 300 # 5 minutes in seconds for feature engineering
TRAIN_TEST_SPLIT_RATIO = 0.8 # 80% for training, 20% for validation
RANDOM_SEED = 42 # For reproducibility

NUM_PATIENTS_TO_PROCESS = 100 # Increased to 100 patients for this test run

# --- Helper Functions (from previous code) ---
def calculate_slope(y):
    """Calculates the slope of a series, handling NaNs."""
    y_clean = y.dropna()
    if len(y_clean) < 2:
        return np.nan
    return np.polyfit(np.arange(len(y_clean)), y_clean, 1)[0]

def generate_patient_features(case_ids: list, vital_files_dir: str, tracks_to_load: list,
                               window_size: int, input_vitals: list, target_vital: str):
    """
    Generator function to load patient data, engineer features, and yield processed DataFrames.
    """
    feature_cols_template = []
    for col in input_vitals:
        feature_cols_template.extend([
            f'{col}_mean', f'{col}_std', f'{col}_min', f'{col}_max', f'{col}_trend'
        ])

    for i, case_id in enumerate(case_ids):
        case_filename = f'{case_id:04d}.vital'
        file_path = os.path.join(vital_files_dir, case_filename)

        if not os.path.exists(file_path):
            print(f"Warning: File '{file_path}' not found for Case {case_id}. Skipping.")
            continue

        try:
            vf = vitaldb.VitalFile(file_path)
            df_raw = vf.to_pandas(tracks_to_load, interval=1)

            df_model = df_raw.copy()

            for col in input_vitals:
                df_model[f'{col}_mean'] = df_model[col].rolling(window=window_size, min_periods=1).mean()
                df_model[f'{col}_std'] = df_model[col].rolling(window=window_size, min_periods=1).std()
                df_model[f'{col}_min'] = df_model[col].rolling(window=window_size, min_periods=1).min()
                df_model[f'{col}_max'] = df_model[col].rolling(window=window_size, min_periods=1).max()
                df_model[f'{col}_trend'] = df_model[col].rolling(window=window_size, min_periods=2).apply(calculate_slope, raw=False)

            feature_cols = [f for f in feature_cols_template if f in df_model.columns]
            final_cols = feature_cols + [target_vital]
            df_processed = df_model[final_cols].copy()

            df_processed = df_processed.dropna(subset=[target_vital]).dropna(how='all', subset=feature_cols)

            if not df_processed.empty:
                yield df_processed
            else:
                print(f"No valid data points after feature engineering for Case {case_id}. Skipping.")

        except Exception as e:
            print(f"Error processing Case {case_id}: {e}. Skipping.")

# --- Test Execution for Step 4 ---
print(f"--- Step 4: XGBoost Training Test (First {NUM_PATIENTS_TO_PROCESS} Patients) ---")

# Ensure the directory for downloaded files exists
os.makedirs(VITAL_FILES_LOCAL_DIR, exist_ok=True)

# Download only the first NUM_PATIENTS_TO_PROCESS files if not already present
s3_source_path = 's3://physionet-open/vitaldb/1.0.0/vital_files/'
for i in range(1, NUM_PATIENTS_TO_PROCESS + 1):
    file_name = f'{i:04d}.vital'
    local_file_path = os.path.join(VITAL_FILES_LOCAL_DIR, file_name)
    if not os.path.exists(local_file_path):
        single_file_s3_path = os.path.join(s3_source_path, file_name)
        single_download_command = f'aws s3 cp --no-sign-request {single_file_s3_path} {local_file_path}'
        os.system(single_download_command)
        print(f"Downloaded {file_name}")
    # else: # Uncomment if you want to see messages for already existing files
    #     print(f"File {file_name} already exists. Skipping download.")
print(f"Download of first {NUM_PATIENTS_TO_PROCESS} files complete (or skipped if already present).")


# Use only the first NUM_PATIENTS_TO_PROCESS for training
all_case_ids = list(range(1, NUM_PATIENTS_TO_PROCESS + 1))

# Split case IDs into training and validation sets (patient-level split)
train_case_ids, val_case_ids = train_test_split(
    all_case_ids, test_size=(1 - TRAIN_TEST_SPLIT_RATIO), random_state=RANDOM_SEED
)

print(f"Total cases for training/validation: {len(all_case_ids)}")
print(f"Training cases (randomly selected patient IDs): {len(train_case_ids)}")
print(f"Validation cases (randomly selected patient IDs): {len(val_case_ids)}")

# Collect training data with progress updates
print("\nCollecting training data...")
X_train_list = []
y_train_list = []
for i, df_patient in enumerate(generate_patient_features(train_case_ids, VITAL_FILES_LOCAL_DIR, TRACKS_FOR_MODEL,
                                            ROLLING_WINDOW_SIZE, INPUT_VITALS, TARGET_VITAL)):
    X_train_list.append(df_patient.drop(columns=[TARGET_VITAL]))
    y_train_list.append(df_patient[TARGET_VITAL])
    if (i + 1) % 10 == 0 or (i + 1) == len(train_case_ids): # Update every 10 patients or at the end
        print(f"  Processed {i+1}/{len(train_case_ids)} training patients. Current data points: {sum(len(x) for x in X_train_list)}")

if not X_train_list:
    print("No training data collected. Cannot proceed with training.")
    exit()

X_train = pd.concat(X_train_list, ignore_index=True)
y_train = pd.concat(y_train_list, ignore_index=True)
print(f"Training data shape: X={X_train.shape}, y={y_train.shape}")

# Collect validation data with progress updates
print("\nCollecting validation data...")
X_val_list = []
y_val_list = []
for i, df_patient in enumerate(generate_patient_features(val_case_ids, VITAL_FILES_LOCAL_DIR, TRACKS_FOR_MODEL,
                                            ROLLING_WINDOW_SIZE, INPUT_VITALS, TARGET_VITAL)):
    X_val_list.append(df_patient.drop(columns=[TARGET_VITAL]))
    y_val_list.append(df_patient[TARGET_VITAL])
    if (i + 1) % 5 == 0 or (i + 1) == len(val_case_ids): # Update every 5 patients or at the end
        print(f"  Processed {i+1}/{len(val_case_ids)} validation patients. Current data points: {sum(len(x) for x in X_val_list)}")

if not X_val_list:
    print("No validation data collected. Cannot evaluate model.")
    X_val = pd.DataFrame()
    y_val = pd.Series()
else:
    X_val = pd.concat(X_val_list, ignore_index=True)
    y_val = pd.concat(y_val_list, ignore_index=True)
    print(f"Validation data shape: X={X_val.shape}, y={y_val.shape}")


print("\nTraining XGBoost Regressor model with validation monitoring...")
# Initialize and train the XGBoost model
# Set eval_metric and early_stopping_rounds in the constructor to avoid deprecation warnings
model = XGBRegressor(
    objective='reg:squarederror',
    n_estimators=200,             # Increased estimators back to 200
    learning_rate=0.1,
    max_depth=5,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=RANDOM_SEED,
    n_jobs=-1,
    tree_method='hist',
    eval_metric='rmse',           # Set eval_metric in constructor
    early_stopping_rounds=20      # Set early_stopping_rounds in constructor
)

# Now, fit method only needs eval_set and verbose (or verbose_eval for older versions)
model.fit(X_train, y_train,
          eval_set=[(X_train, y_train), (X_val, y_val)],
          verbose=True # Set to True to see evaluation metrics during training
         )
print("Model training complete.")

# Save the trained model
model.save_model(MODEL_SAVE_PATH)
print(f"Model saved to {MODEL_SAVE_PATH}")

# Evaluate the model
if not X_val.empty:
    print("\nFinal model evaluation on validation set...")
    y_pred = model.predict(X_val)

    mae = mean_absolute_error(y_val, y_pred)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    r2 = r2_score(y_val, y_pred)

    print(f"Validation MAE: {mae:.2f}")
    print(f"Validation RMSE: {rmse:.2f}")
    print(f"Validation R-squared: {r2:.2f}")

    # Plotting predictions vs actual for a subset
    plt.figure(figsize=(10, 6))
    plt.scatter(y_val, y_pred, alpha=0.3)
    # Plot a perfect prediction line
    min_val = min(y_val.min(), y_pred.min())
    max_val = max(y_val.max(), y_pred.max())
    plt.plot([min_val, max_val], [min_val, max_val], 'r--', lw=2)
    plt.xlabel("Actual BIS Score")
    plt.ylabel("Predicted BIS Score")
    plt.title(f"Actual vs. Predicted BIS Score (Validation Set, {NUM_PATIENTS_TO_PROCESS} Patients)")
    plt.grid(True)
    plt.show()
else:
    print("Skipping final model evaluation as no validation data was collected.")

# --- Phase 4: Combined Graph (Vectorization/Averaging) ---
print(f"\n--- Phase 4: Generating Combined Average Graph ---")

# Tracks to include in the average plot (raw data)
AVERAGE_PLOT_TRACKS = INPUT_VITALS + [TARGET_VITAL]

# Collect all data for averaging (only the raw tracks needed for this plot)
all_patient_raw_dfs = []
print(f"Collecting raw data from all {NUM_PATIENTS_TO_PROCESS} patients for averaging...")
for case_id in all_case_ids: # Use all_case_ids which is limited to NUM_PATIENTS_TO_PROCESS
    case_filename = f'{case_id:04d}.vital'
    file_path = os.path.join(VITAL_FILES_LOCAL_DIR, case_filename)

    if not os.path.exists(file_path):
        continue

    try:
        vf = vitaldb.VitalFile(file_path)
        df_raw_avg = vf.to_pandas(AVERAGE_PLOT_TRACKS, interval=1)
        all_patient_raw_dfs.append(df_raw_avg)
    except Exception as e:
        print(f"Error loading raw data for averaging for Case {case_id}: {e}. Skipping.")

if not all_patient_raw_dfs:
    print("No data collected for combined average graph. Skipping.")
else:
    print(f"Concatenating raw data from {len(all_patient_raw_dfs)} patients for averaging...")
    combined_raw_df = pd.concat(all_patient_raw_dfs, ignore_index=False)

    print("Calculating average and standard deviation across all patients...")
    average_df = combined_raw_df.groupby(level=0)[AVERAGE_PLOT_TRACKS].mean()
    std_df = combined_raw_df.groupby(level=0)[AVERAGE_PLOT_TRACKS].std()
    count_df = combined_raw_df.groupby(level=0)[AVERAGE_PLOT_TRACKS].count()

    fig_avg, axes_avg = plt.subplots(len(AVERAGE_PLOT_TRACKS), 1, figsize=(18, 5 * len(AVERAGE_PLOT_TRACKS)), sharex=True)
    fig_avg.suptitle(f'Average Vital Signs Across {NUM_PATIENTS_TO_PROCESS} Patients', fontsize=18)

    for i, track in enumerate(AVERAGE_PLOT_TRACKS):
        ax = axes_avg[i] if len(AVERAGE_PLOT_TRACKS) > 1 else axes_avg
        ax.plot(average_df.index, average_df[track], label=f'Average {track.split("/")[-1]}', color='blue')
        ax.fill_between(std_df.index, average_df[track] - std_df[track], average_df[track] + std_df[track],
                        color='blue', alpha=0.2, label='±1 Std Dev')
        ax.set_ylabel(track.split('/')[-1])
        ax.legend(loc='upper right')
        ax.grid(True, linestyle='--', alpha=0.6)
        ax_twin_count = ax.twinx()
        ax_twin_count.plot(count_df.index, count_df[track], color='gray', linestyle=':', alpha=0.5, label='N Patients')
        ax_twin_count.set_ylabel('N Patients', color='gray')
        ax_twin_count.tick_params(axis='y', labelcolor='gray')
        ax_twin_count.legend(loc='upper left')


    axes_avg[-1].set_xlabel('Time (seconds from start of recording)')
    plt.tight_layout(rect=[0, 0.03, 1, 0.97])
    plt.show()

    print("Combined average graph generated.")

# --- Generate individual patient PDFs (as per previous request) ---
# This part is kept separate as it's a large output and might not be needed every time.
# Uncomment the following block if you want to generate the 100-page PDF.
# This will use the files already downloaded in VITAL_FILES_LOCAL_DIR.

from matplotlib.backends.backend_pdf import PdfPages

print(f"\n--- Generating individual patient plots PDF (up to {NUM_PATIENTS_TO_PROCESS} pages) ---")
INDIVIDUAL_PDF_OUTPUT_DIR = 'individual_patient_pdfs_3_subplots'
os.makedirs(INDIVIDUAL_PDF_OUTPUT_DIR, exist_ok=True)
individual_pdf_path = os.path.join(INDIVIDUAL_PDF_OUTPUT_DIR, f'all_patient_vitals_3_subplots_{NUM_PATIENTS_TO_PROCESS}_patients.pdf')
def plot_and_save_single_patient_pdf(case_id: int, vital_files_dir: str, pdf_pages: PdfPages):
    case_filename = f'{case_id:04d}.vital'
    file_path = os.path.join(vital_files_dir, case_filename)
    print(f"Plotting Case {case_id} for PDF...")
    if not os.path.exists(file_path):
        print(f"ERROR: File '{file_path}' not found for Case {case_id}. Skipping PDF page.")
        return
    try:
        vf = vitaldb.VitalFile(file_path)
        tracks_to_load_plot = [
            'Solar8000/HR',
            'Solar8000/ART_MBP',
            'Solar8000/PLETH_SPO2',
            'Solar8000/ETCO2',
            'BIS/BIS',
            'EVENT'
        ]
        df = vf.to_pandas(tracks_to_load_plot, interval=1)
        start_time, end_time = df.index.min(), df.index.max()
        if 'Solar8000/ART_MBP' in df.columns:
            valid_start = df['Solar8000/ART_MBP'].first_valid_index()
            valid_end = df['Solar8000/ART_MBP'].last_valid_index()
            if valid_start is not None and valid_end is not None:
                start_time = valid_start
                end_time = valid_end
        start_time = max(df.index.min(), start_time - 300)
        end_time = min(df.index.max(), end_time + 300)
        events = df['EVENT'].dropna()
        fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(20, 15), sharex=True)
        fig.suptitle(f'Comprehensive Patient View (Case {case_id:04d})', fontsize=18)
        ax1.plot(df.index, df['Solar8000/HR'], label='Heart Rate (bpm)', color='dodgerblue', marker='.', markersize=2, linestyle='-')
        ax1.plot(df.index, df['Solar8000/ART_MBP'], label='Mean Arterial Pressure (mmHg)', color='orangered', marker='.', markersize=2, linestyle='-')
        ax1.set_ylabel('Core Vitals')
        ax1.legend(loc='upper left')
        ax1.grid(True, linestyle='--', alpha=0.6)
        ax1.set_ylim(0, 150)
        ax2.plot(df.index, df['Solar8000/PLETH_SPO2'], label='SpO2 (%)', color='darkcyan', marker='.', markersize=2, linestyle='-')
        ax2.set_ylabel('SpO2 (%)', color='darkcyan')
        ax2.tick_params(axis='y', labelcolor='darkcyan')
        ax2.set_ylim(85, 101)
        ax2_twin = ax2.twinx()
        ax2_twin.plot(df.index, df['Solar8000/ETCO2'], label='EtCO2 (mmHg)', color='gold', marker='.', markersize=2, linestyle='-')
        ax2_twin.set_ylabel('EtCO2 (mmHg)', color='gold')
        ax2_twin.tick_params(axis='y', labelcolor='gold')
        ax2_twin.set_ylim(0, 60)
        lines, labels = ax2.get_legend_handles_labels()
        lines2, labels2 = ax2_twin.get_legend_handles_labels()
        ax2_twin.legend(lines + lines2, labels + labels2, loc='upper left')
        ax2.grid(True, linestyle='--', alpha=0.6)
        ax3.plot(df.index, df['BIS/BIS'], label='BIS Score', color='green')
        ax3.axhspan(40, 60, color='green', alpha=0.1, label='Target Anesthesia Range')
        ax3.set_ylabel('Anesthetic Depth (BIS)')
        ax3.legend(loc='upper left')
        ax3.grid(True, linestyle='--', alpha=0.6)
        ax3.set_ylim(0, 100)
        for time, text in events.items():
            for ax in [ax1, ax2, ax3]:
                ax.axvline(x=time, color='red', linestyle='--', linewidth=1.5)
            ax1.text(time + 30, 140, text, rotation=90, verticalalignment='top', color='red', fontsize=10)
        ax1.set_xlim(start_time, end_time)
        plt.tight_layout(rect=[0, 0.03, 1, 0.97])
        pdf_pages.savefig(fig)
        plt.close(fig)
        print(f"Successfully added Case {case_id} to PDF.")
    except Exception as e:
        print(f"Error plotting Case {case_id} for PDF: {e}")
with PdfPages(individual_pdf_path) as pdf:
    for case_id in range(1, NUM_PATIENTS_TO_PROCESS + 1):
        plot_and_save_single_patient_pdf(case_id, VITAL_FILES_LOCAL_DIR, pdf)
print(f"Individual patient plots combined into: {individual_pdf_path}")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 66.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 83.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.5/570.5 kB 24.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 6.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.3 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.4 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.1 which is incompatible.
# pandas-gbq 0.29.1 requires google-api-core<3.0.0,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.5.1 which is incompatible.
# google-cloud-storage 2.19.0 requires google-api-core<3.0.0dev,>=2.15.0, but you have google-api-core 1.34.1 which is incompatible.
# dataproc-spark-connect 0.7.5 requires google-api-core>=2.19, but you have google-api-core 1.34.1 which is incompatible.
# sphinx 8.2.3 requires docutils<0.22,>=0.20, but you have docutils 0.19 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.8.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# --- Step 4: XGBoost Training Test (First 100 Patients) ---
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0001.vital to vital_files_full_dataset_1000/0001.vital
# Downloaded 0001.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0002.vital to vital_files_full_dataset_1000/0002.vital
# Downloaded 0002.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0003.vital to vital_files_full_dataset_1000/0003.vital
# Downloaded 0003.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0004.vital to vital_files_full_dataset_1000/0004.vital
# Downloaded 0004.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0005.vital to vital_files_full_dataset_1000/0005.vital
# Downloaded 0005.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0006.vital to vital_files_full_dataset_1000/0006.vital
# Downloaded 0006.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0007.vital to vital_files_full_dataset_1000/0007.vital
# Downloaded 0007.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0008.vital to vital_files_full_dataset_1000/0008.vital
# Downloaded 0008.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0009.vital to vital_files_full_dataset_1000/0009.vital
# Downloaded 0009.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0010.vital to vital_files_full_dataset_1000/0010.vital
# Downloaded 0010.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0011.vital to vital_files_full_dataset_1000/0011.vital
# Downloaded 0011.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0012.vital to vital_files_full_dataset_1000/0012.vital
# Downloaded 0012.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0013.vital to vital_files_full_dataset_1000/0013.vital
# Downloaded 0013.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0014.vital to vital_files_full_dataset_1000/0014.vital
# Downloaded 0014.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0015.vital to vital_files_full_dataset_1000/0015.vital
# Downloaded 0015.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0016.vital to vital_files_full_dataset_1000/0016.vital
# Downloaded 0016.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0017.vital to vital_files_full_dataset_1000/0017.vital
# Downloaded 0017.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0018.vital to vital_files_full_dataset_1000/0018.vital
# Downloaded 0018.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0019.vital to vital_files_full_dataset_1000/0019.vital
# Downloaded 0019.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0020.vital to vital_files_full_dataset_1000/0020.vital
# Downloaded 0020.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0021.vital to vital_files_full_dataset_1000/0021.vital
# Downloaded 0021.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0022.vital to vital_files_full_dataset_1000/0022.vital
# Downloaded 0022.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0023.vital to vital_files_full_dataset_1000/0023.vital
# Downloaded 0023.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0024.vital to vital_files_full_dataset_1000/0024.vital
# Downloaded 0024.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0025.vital to vital_files_full_dataset_1000/0025.vital
# Downloaded 0025.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0026.vital to vital_files_full_dataset_1000/0026.vital
# Downloaded 0026.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0027.vital to vital_files_full_dataset_1000/0027.vital
# Downloaded 0027.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0028.vital to vital_files_full_dataset_1000/0028.vital
# Downloaded 0028.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0029.vital to vital_files_full_dataset_1000/0029.vital
# Downloaded 0029.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0030.vital to vital_files_full_dataset_1000/0030.vital
# Downloaded 0030.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0031.vital to vital_files_full_dataset_1000/0031.vital
# Downloaded 0031.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0032.vital to vital_files_full_dataset_1000/0032.vital
# Downloaded 0032.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0033.vital to vital_files_full_dataset_1000/0033.vital
# Downloaded 0033.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0034.vital to vital_files_full_dataset_1000/0034.vital
# Downloaded 0034.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0035.vital to vital_files_full_dataset_1000/0035.vital
# Downloaded 0035.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0036.vital to vital_files_full_dataset_1000/0036.vital
# Downloaded 0036.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0037.vital to vital_files_full_dataset_1000/0037.vital
# Downloaded 0037.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0038.vital to vital_files_full_dataset_1000/0038.vital
# Downloaded 0038.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0039.vital to vital_files_full_dataset_1000/0039.vital
# Downloaded 0039.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0040.vital to vital_files_full_dataset_1000/0040.vital
# Downloaded 0040.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0041.vital to vital_files_full_dataset_1000/0041.vital
# Downloaded 0041.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0042.vital to vital_files_full_dataset_1000/0042.vital
# Downloaded 0042.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0043.vital to vital_files_full_dataset_1000/0043.vital
# Downloaded 0043.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0044.vital to vital_files_full_dataset_1000/0044.vital
# Downloaded 0044.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0045.vital to vital_files_full_dataset_1000/0045.vital
# Downloaded 0045.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0046.vital to vital_files_full_dataset_1000/0046.vital
# Downloaded 0046.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0047.vital to vital_files_full_dataset_1000/0047.vital
# Downloaded 0047.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0048.vital to vital_files_full_dataset_1000/0048.vital
# Downloaded 0048.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0049.vital to vital_files_full_dataset_1000/0049.vital
# Downloaded 0049.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0050.vital to vital_files_full_dataset_1000/0050.vital
# Downloaded 0050.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0051.vital to vital_files_full_dataset_1000/0051.vital
# Downloaded 0051.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0052.vital to vital_files_full_dataset_1000/0052.vital
# Downloaded 0052.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0053.vital to vital_files_full_dataset_1000/0053.vital
# Downloaded 0053.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0054.vital to vital_files_full_dataset_1000/0054.vital
# Downloaded 0054.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0055.vital to vital_files_full_dataset_1000/0055.vital
# Downloaded 0055.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0056.vital to vital_files_full_dataset_1000/0056.vital
# Downloaded 0056.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0057.vital to vital_files_full_dataset_1000/0057.vital
# Downloaded 0057.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0058.vital to vital_files_full_dataset_1000/0058.vital
# Downloaded 0058.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0059.vital to vital_files_full_dataset_1000/0059.vital
# Downloaded 0059.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0060.vital to vital_files_full_dataset_1000/0060.vital
# Downloaded 0060.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0061.vital to vital_files_full_dataset_1000/0061.vital
# Downloaded 0061.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0062.vital to vital_files_full_dataset_1000/0062.vital
# Downloaded 0062.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0063.vital to vital_files_full_dataset_1000/0063.vital
# Downloaded 0063.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0064.vital to vital_files_full_dataset_1000/0064.vital
# Downloaded 0064.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0065.vital to vital_files_full_dataset_1000/0065.vital
# Downloaded 0065.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0066.vital to vital_files_full_dataset_1000/0066.vital
# Downloaded 0066.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0067.vital to vital_files_full_dataset_1000/0067.vital
# Downloaded 0067.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0068.vital to vital_files_full_dataset_1000/0068.vital
# Downloaded 0068.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0069.vital to vital_files_full_dataset_1000/0069.vital
# Downloaded 0069.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0070.vital to vital_files_full_dataset_1000/0070.vital
# Downloaded 0070.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0071.vital to vital_files_full_dataset_1000/0071.vital
# Downloaded 0071.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0072.vital to vital_files_full_dataset_1000/0072.vital
# Downloaded 0072.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0073.vital to vital_files_full_dataset_1000/0073.vital
# Downloaded 0073.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0074.vital to vital_files_full_dataset_1000/0074.vital
# Downloaded 0074.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0075.vital to vital_files_full_dataset_1000/0075.vital
# Downloaded 0075.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0076.vital to vital_files_full_dataset_1000/0076.vital
# Downloaded 0076.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0077.vital to vital_files_full_dataset_1000/0077.vital
# Downloaded 0077.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0078.vital to vital_files_full_dataset_1000/0078.vital
# Downloaded 0078.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0079.vital to vital_files_full_dataset_1000/0079.vital
# Downloaded 0079.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0080.vital to vital_files_full_dataset_1000/0080.vital
# Downloaded 0080.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0081.vital to vital_files_full_dataset_1000/0081.vital
# Downloaded 0081.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0082.vital to vital_files_full_dataset_1000/0082.vital
# Downloaded 0082.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0083.vital to vital_files_full_dataset_1000/0083.vital
# Downloaded 0083.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0084.vital to vital_files_full_dataset_1000/0084.vital
# Downloaded 0084.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0085.vital to vital_files_full_dataset_1000/0085.vital
# Downloaded 0085.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0086.vital to vital_files_full_dataset_1000/0086.vital
# Downloaded 0086.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0087.vital to vital_files_full_dataset_1000/0087.vital
# Downloaded 0087.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0088.vital to vital_files_full_dataset_1000/0088.vital
# Downloaded 0088.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0089.vital to vital_files_full_dataset_1000/0089.vital
# Downloaded 0089.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0090.vital to vital_files_full_dataset_1000/0090.vital
# Downloaded 0090.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0091.vital to vital_files_full_dataset_1000/0091.vital
# Downloaded 0091.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0092.vital to vital_files_full_dataset_1000/0092.vital
# Downloaded 0092.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0093.vital to vital_files_full_dataset_1000/0093.vital
# Downloaded 0093.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0094.vital to vital_files_full_dataset_1000/0094.vital
# Downloaded 0094.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0095.vital to vital_files_full_dataset_1000/0095.vital
# Downloaded 0095.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0096.vital to vital_files_full_dataset_1000/0096.vital
# Downloaded 0096.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0097.vital to vital_files_full_dataset_1000/0097.vital
# Downloaded 0097.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0098.vital to vital_files_full_dataset_1000/0098.vital
# Downloaded 0098.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0099.vital to vital_files_full_dataset_1000/0099.vital
# Downloaded 0099.vital
# download: s3://physionet-open/vitaldb/1.0.0/vital_files/0100.vital to vital_files_full_dataset_1000/0100.vital
# Downloaded 0100.vital
# Download of first 100 files complete (or skipped if already present).
# Total cases for training/validation: 100
# Training cases (randomly selected patient IDs): 80
# Validation cases (randomly selected patient IDs): 20
#
# Collecting training data...
# No valid data points after feature engineering for Case 73. Skipping.
#   Processed 10/80 training patients. Current data points: 187373
# No valid data points after feature engineering for Case 86. Skipping.
#   Processed 20/80 training patients. Current data points: 316880
# No valid data points after feature engineering for Case 28. Skipping.
# No valid data points after feature engineering for Case 63. Skipping.
# No valid data points after feature engineering for Case 18. Skipping.
# No valid data points after feature engineering for Case 39. Skipping.
#   Processed 30/80 training patients. Current data points: 465641
# No valid data points after feature engineering for Case 51. Skipping.
#   Processed 40/80 training patients. Current data points: 569591
# No valid data points after feature engineering for Case 99. Skipping.
#   Processed 50/80 training patients. Current data points: 662870
#   Processed 60/80 training patients. Current data points: 758500
# No valid data points after feature engineering for Case 15. Skipping.
#   Processed 70/80 training patients. Current data points: 866487
# Training data shape: X=(882055, 20), y=(882055,)
#
# Collecting validation data...
#   Processed 5/20 validation patients. Current data points: 56398
# No valid data points after feature engineering for Case 23. Skipping.
# No valid data points after feature engineering for Case 11. Skipping.
#   Processed 10/20 validation patients. Current data points: 125878
# No valid data points after feature engineering for Case 32. Skipping.
# Validation data shape: X=(230345, 20), y=(230345,)
#
# Training XGBoost Regressor model with validation monitoring...
# [0]	validation_0-rmse:15.98595	validation_1-rmse:15.79800
# [1]	validation_0-rmse:15.62022	validation_1-rmse:15.49116
# [2]	validation_0-rmse:15.30434	validation_1-rmse:15.29362
# [3]	validation_0-rmse:15.04176	validation_1-rmse:15.14713
# [4]	validation_0-rmse:14.80258	validation_1-rmse:15.02453
# [5]	validation_0-rmse:14.58396	validation_1-rmse:14.93822
# [6]	validation_0-rmse:14.40705	validation_1-rmse:14.86230
# [7]	validation_0-rmse:14.24959	validation_1-rmse:14.77832
# [8]	validation_0-rmse:14.12128	validation_1-rmse:14.67445
# [9]	validation_0-rmse:14.00019	validation_1-rmse:14.66021
# [10]	validation_0-rmse:13.88997	validation_1-rmse:14.66804
# [11]	validation_0-rmse:13.78832	validation_1-rmse:14.67798
# [12]	validation_0-rmse:13.70303	validation_1-rmse:14.68755
# [13]	validation_0-rmse:13.62781	validation_1-rmse:14.68369
# [14]	validation_0-rmse:13.55346	validation_1-rmse:14.66092
# [15]	validation_0-rmse:13.47863	validation_1-rmse:14.68254
# [16]	validation_0-rmse:13.38186	validation_1-rmse:14.69091
# [17]	validation_0-rmse:13.31737	validation_1-rmse:14.69403
# [18]	validation_0-rmse:13.25433	validation_1-rmse:14.73267
# [19]	validation_0-rmse:13.16992	validation_1-rmse:14.73564
# [20]	validation_0-rmse:13.13351	validation_1-rmse:14.74874
# [21]	validation_0-rmse:13.08777	validation_1-rmse:14.76773
# [22]	validation_0-rmse:13.00912	validation_1-rmse:14.76855
# [23]	validation_0-rmse:12.93991	validation_1-rmse:14.71343
# [24]	validation_0-rmse:12.90338	validation_1-rmse:14.74832
# [25]	validation_0-rmse:12.83701	validation_1-rmse:14.77424
# [26]	validation_0-rmse:12.77009	validation_1-rmse:14.79673
# [27]	validation_0-rmse:12.71897	validation_1-rmse:14.81008
# [28]	validation_0-rmse:12.67605	validation_1-rmse:14.79658
# [29]	validation_0-rmse:12.62919	validation_1-rmse:14.77452
# Model training complete.
# Model saved to vitaldb_bis_model_test_100_patients.json
#
# Final model evaluation on validation set...
# Validation MAE: 9.60
# Validation RMSE: 14.66
# Validation R-squared: 0.17
# --- Phase 4: Generating Combined Average Graph ---
# Collecting raw data from all 100 patients for averaging...
# Concatenating raw data from 100 patients for averaging...
# Calculating average and standard deviation across all patients...
# Combined average graph generated.
#
# --- Generating individual patient plots PDF (up to 100 pages) ---
# Plotting Case 1 for PDF...
# Successfully added Case 1 to PDF.
# Plotting Case 2 for PDF...
# Successfully added Case 2 to PDF.
# Plotting Case 3 for PDF...
# Successfully added Case 3 to PDF.
# Plotting Case 4 for PDF...
# Successfully added Case 4 to PDF.
# Plotting Case 5 for PDF...
# Successfully added Case 5 to PDF.
# Plotting Case 6 for PDF...
# Successfully added Case 6 to PDF.
# Plotting Case 7 for PDF...
# Successfully added Case 7 to PDF.
# Plotting Case 8 for PDF...
# Successfully added Case 8 to PDF.
# Plotting Case 9 for PDF...
# Successfully added Case 9 to PDF.
# Plotting Case 10 for PDF...
# Successfully added Case 10 to PDF.
# Plotting Case 11 for PDF...
# Successfully added Case 11 to PDF.
# Plotting Case 12 for PDF...
# Successfully added Case 12 to PDF.
# Plotting Case 13 for PDF...
# Successfully added Case 13 to PDF.
# Plotting Case 14 for PDF...
# Successfully added Case 14 to PDF.
# Plotting Case 15 for PDF...
# Successfully added Case 15 to PDF.
# Plotting Case 16 for PDF...
# Successfully added Case 16 to PDF.
# Plotting Case 17 for PDF...
# Successfully added Case 17 to PDF.
# Plotting Case 18 for PDF...
# Successfully added Case 18 to PDF.
# Plotting Case 19 for PDF...
# Successfully added Case 19 to PDF.
# Plotting Case 20 for PDF...
# Successfully added Case 20 to PDF.
# Plotting Case 21 for PDF...
# Successfully added Case 21 to PDF.
# Plotting Case 22 for PDF...
# Successfully added Case 22 to PDF.
# Plotting Case 23 for PDF...
# Successfully added Case 23 to PDF.
# Plotting Case 24 for PDF...
# Successfully added Case 24 to PDF.
# Plotting Case 25 for PDF...
# Successfully added Case 25 to PDF.
# Plotting Case 26 for PDF...
# Successfully added Case 26 to PDF.
# Plotting Case 27 for PDF...
# Successfully added Case 27 to PDF.
# Plotting Case 28 for PDF...
# Successfully added Case 28 to PDF.
# Plotting Case 29 for PDF...
# Successfully added Case 29 to PDF.
# Plotting Case 30 for PDF...
# Successfully added Case 30 to PDF.
# Plotting Case 31 for PDF...
# Successfully added Case 31 to PDF.
# Plotting Case 32 for PDF...
# Successfully added Case 32 to PDF.
# Plotting Case 33 for PDF...
# Successfully added Case 33 to PDF.
# Plotting Case 34 for PDF...
# Successfully added Case 34 to PDF.
# Plotting Case 35 for PDF...
# Successfully added Case 35 to PDF.
# Plotting Case 36 for PDF...
# Successfully added Case 36 to PDF.
# Plotting Case 37 for PDF...
# Successfully added Case 37 to PDF.
# Plotting Case 38 for PDF...
# Successfully added Case 38 to PDF.
# Plotting Case 39 for PDF...
# Successfully added Case 39 to PDF.
# Plotting Case 40 for PDF...
# Successfully added Case 40 to PDF.
# Plotting Case 41 for PDF...
# Successfully added Case 41 to PDF.
# Plotting Case 42 for PDF...
# Successfully added Case 42 to PDF.
# Plotting Case 43 for PDF...
# Successfully added Case 43 to PDF.
# Plotting Case 44 for PDF...
# Successfully added Case 44 to PDF.
# Plotting Case 45 for PDF...
# Successfully added Case 45 to PDF.
# Plotting Case 46 for PDF...
# Successfully added Case 46 to PDF.
# Plotting Case 47 for PDF...
# Successfully added Case 47 to PDF.
# Plotting Case 48 for PDF...
# Successfully added Case 48 to PDF.
# Plotting Case 49 for PDF...
# Successfully added Case 49 to PDF.
# Plotting Case 50 for PDF...
# Successfully added Case 50 to PDF.
# Plotting Case 51 for PDF...
# Successfully added Case 51 to PDF.
# Plotting Case 52 for PDF...
# Successfully added Case 52 to PDF.
# Plotting Case 53 for PDF...
# Successfully added Case 53 to PDF.
# Plotting Case 54 for PDF...
# Successfully added Case 54 to PDF.
# Plotting Case 55 for PDF...
# Successfully added Case 55 to PDF.
# Plotting Case 56 for PDF...
# Successfully added Case 56 to PDF.
# Plotting Case 57 for PDF...
# Successfully added Case 57 to PDF.
# Plotting Case 58 for PDF...
# Successfully added Case 58 to PDF.
# Plotting Case 59 for PDF...
# Successfully added Case 59 to PDF.
# Plotting Case 60 for PDF...
# Successfully added Case 60 to PDF.
# Plotting Case 61 for PDF...
# Successfully added Case 61 to PDF.
# Plotting Case 62 for PDF...
# Successfully added Case 62 to PDF.
# Plotting Case 63 for PDF...
# Successfully added Case 63 to PDF.
# Plotting Case 64 for PDF...
# Successfully added Case 64 to PDF.
# Plotting Case 65 for PDF...
# Successfully added Case 65 to PDF.
# Plotting Case 66 for PDF...
# Successfully added Case 66 to PDF.
# Plotting Case 67 for PDF...
# Successfully added Case 67 to PDF.
# Plotting Case 68 for PDF...
# Successfully added Case 68 to PDF.
# Plotting Case 69 for PDF...
# Successfully added Case 69 to PDF.
# Plotting Case 70 for PDF...
# Successfully added Case 70 to PDF.
# Plotting Case 71 for PDF...
# Successfully added Case 71 to PDF.
# Plotting Case 72 for PDF...
# Successfully added Case 72 to PDF.
# Plotting Case 73 for PDF...
# Successfully added Case 73 to PDF.
# Plotting Case 74 for PDF...
# Successfully added Case 74 to PDF.
# Plotting Case 75 for PDF...
# Successfully added Case 75 to PDF.
# Plotting Case 76 for PDF...
# Successfully added Case 76 to PDF.
# Plotting Case 77 for PDF...
# Successfully added Case 77 to PDF.
# Plotting Case 78 for PDF...
# Successfully added Case 78 to PDF.
# Plotting Case 79 for PDF...
# Successfully added Case 79 to PDF.
# Plotting Case 80 for PDF...
# Successfully added Case 80 to PDF.
# Plotting Case 81 for PDF...
# Successfully added Case 81 to PDF.
# Plotting Case 82 for PDF...
# Successfully added Case 82 to PDF.
# Plotting Case 83 for PDF...
# Successfully added Case 83 to PDF.
# Plotting Case 84 for PDF...
# Successfully added Case 84 to PDF.
# Plotting Case 85 for PDF...
# Successfully added Case 85 to PDF.
# Plotting Case 86 for PDF...
# Successfully added Case 86 to PDF.
# Plotting Case 87 for PDF...
# Successfully added Case 87 to PDF.
# Plotting Case 88 for PDF...
# Successfully added Case 88 to PDF.
# Plotting Case 89 for PDF...
# Successfully added Case 89 to PDF.
# Plotting Case 90 for PDF...
# Successfully added Case 90 to PDF.
# Plotting Case 91 for PDF...
# Successfully added Case 91 to PDF.
# Plotting Case 92 for PDF...
# Successfully added Case 92 to PDF.
# Plotting Case 93 for PDF...
# Successfully added Case 93 to PDF.
# Plotting Case 94 for PDF...
# Successfully added Case 94 to PDF.
# Plotting Case 95 for PDF...
# Successfully added Case 95 to PDF.
# Plotting Case 96 for PDF...
# Successfully added Case 96 to PDF.
# Plotting Case 97 for PDF...
# Successfully added Case 97 to PDF.
# Plotting Case 98 for PDF...
# Successfully added Case 98 to PDF.
# Plotting Case 99 for PDF...
# Successfully added Case 99 to PDF.
# Plotting Case 100 for PDF...
# Successfully added Case 100 to PDF.
# Individual patient plots combined into: individual_patient_pdfs_3_subplots/all_patient_vitals_3_subplots_100_patients.pdf
