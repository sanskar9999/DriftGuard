# %%
# !pip install vitaldb matplotlib awscli pypdf --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 62.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.5/305.5 kB 20.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.5/570.5 kB 36.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 81.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.1 which is incompatible.
# cudf-cu12 25.2.1 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.1 which is incompatible.
# sphinx 8.2.3 requires docutils<0.22,>=0.20, but you have docutils 0.19 which is incompatible.
# dask-cudf-cu12 25.2.2 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.1 which is incompatible.

# %%
import vitaldb
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

def plot_and_save_patient_data(case_id: int, output_dir: str, pdf_pages: PdfPages):
    """
    Downloads, plots, and saves vital signs data for a single patient to a PDF page.

    Args:
        case_id: The ID of the patient case (e.g., 1 for 0001.vital).
        output_dir: The directory where temporary files might be stored.
        pdf_pages: A PdfPages object to which the generated figure will be added.
    """
    # Format case_id to match filename convention (e.g., 1 -> 0001)
    case_filename = f'{case_id:04d}.vital'
    file_path = os.path.join(output_dir, case_filename)
    s3_path = f's3://physionet-open/vitaldb/1.0.0/vital_files/{case_filename}'

    print(f"Processing Case {case_id}...")

    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Download the vital file
    download_command = f'aws s3 cp --no-sign-request {s3_path} {file_path}'
    os.system(download_command)

    if not os.path.exists(file_path):
        print(f"ERROR: Download failed for '{case_filename}'. File not found.")
        return

    try:
        vf = vitaldb.VitalFile(file_path)

        # Define tracks to load - reverted to the original set for the 3-subplot view
        tracks_to_load = [
            'Solar8000/HR',
            'Solar8000/ART_MBP',
            'Solar8000/PLETH_SPO2',
            'Solar8000/ETCO2',
            'BIS/BIS',
            'EVENT'
        ]

        df = vf.to_pandas(tracks_to_load, interval=1)

        # Determine the plotting time range
        start_time, end_time = df.index.min(), df.index.max()
        if 'Solar8000/ART_MBP' in df.columns:
            valid_start = df['Solar8000/ART_MBP'].first_valid_index()
            valid_end = df['Solar8000/ART_MBP'].last_valid_index()
            if valid_start is not None and valid_end is not None:
                start_time = valid_start
                end_time = valid_end
        # Add padding to the time range
        start_time = max(df.index.min(), start_time - 300)
        end_time = min(df.index.max(), end_time + 300)


        events = df['EVENT'].dropna()

        # Create the figure and 3 subplots, sharing the x-axis
        fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(20, 15), sharex=True) # Reverted to 3 subplots
        fig.suptitle(f'Comprehensive Patient View (Case {case_id:04d})', fontsize=18) # Dynamic title

        # --- Subplot 1: Core Vitals (HR, MAP) ---
        ax1.plot(df.index, df['Solar8000/HR'], label='Heart Rate (bpm)', color='dodgerblue', marker='.', markersize=2, linestyle='-')
        ax1.plot(df.index, df['Solar8000/ART_MBP'], label='Mean Arterial Pressure (mmHg)', color='orangered', marker='.', markersize=2, linestyle='-')
        ax1.set_ylabel('Core Vitals')
        ax1.legend(loc='upper left')
        ax1.grid(True, linestyle='--', alpha=0.6)
        ax1.set_ylim(0, 150)

        # --- Subplot 2: Oxygenation and Ventilation (SpO2, EtCO2) ---
        ax2.plot(df.index, df['Solar8000/PLETH_SPO2'], label='SpO2 (%)', color='darkcyan', marker='.', markersize=2, linestyle='-')
        ax2.set_ylabel('SpO2 (%)', color='darkcyan')
        ax2.tick_params(axis='y', labelcolor='darkcyan')
        ax2.set_ylim(85, 101)

        ax2_twin = ax2.twinx()
        ax2_twin.plot(df.index, df['Solar8000/ETCO2'], label='EtCO2 (mmHg)', color='gold', marker='.', markersize=2, linestyle='-')
        ax2_twin.set_ylabel('EtCO2 (mmHg)', color='gold') # Reverted label
        ax2_twin.tick_params(axis='y', labelcolor='gold')
        ax2_twin.set_ylim(0, 60)

        # Combine legends for ax2 and ax2_twin
        lines, labels = ax2.get_legend_handles_labels()
        lines2, labels2 = ax2_twin.get_legend_handles_labels()
        ax2_twin.legend(lines + lines2, labels + labels2, loc='upper left')
        ax2.grid(True, linestyle='--', alpha=0.6)

        # --- Subplot 3: Anesthetic Depth (BIS) ---
        ax3.plot(df.index, df['BIS/BIS'], label='BIS Score', color='green')
        ax3.axhspan(40, 60, color='green', alpha=0.1, label='Target Anesthesia Range')
        ax3.set_ylabel('Anesthetic Depth (BIS)')
        ax3.legend(loc='upper left')
        ax3.grid(True, linestyle='--', alpha=0.6)
        ax3.set_ylim(0, 100)

        # --- No Subplot 4 for Anesthetic Agents ---

        # --- Add Event Markers to all subplots ---
        for time, text in events.items():
            for ax in [ax1, ax2, ax3]: # Apply to 3 subplots only
                ax.axvline(x=time, color='red', linestyle='--', linewidth=1.5)
            ax1.text(time + 30, 140, text, rotation=90, verticalalignment='top', color='red', fontsize=10)

        ax1.set_xlim(start_time, end_time)

        plt.tight_layout(rect=[0, 0.03, 1, 0.97])
        pdf_pages.savefig(fig)
        plt.close(fig)
        print(f"Successfully plotted and added Case {case_id} to PDF.")

    except Exception as e:
        print(f"Error processing Case {case_id}: {e}")
    finally:
        # Clean up the downloaded vital file
        if os.path.exists(file_path):
            os.remove(file_path)
            print(f"Cleaned up '{case_filename}'.")


# --- Main execution for batch processing ---
NUM_PATIENTS = 100 # Set to 100 for full run
OUTPUT_DIR = 'patient_plots'
COMBINED_PDF_FILENAME = 'all_patient_vitals_3_subplots.pdf' # Changed filename to reflect 3 subplots

# Create output directory if it doesn't exist
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Create a PdfPages object to save all plots into a single PDF
combined_pdf_path = os.path.join(OUTPUT_DIR, COMBINED_PDF_FILENAME)
with PdfPages(combined_pdf_path) as pdf:
    for case_id in range(1, NUM_PATIENTS + 1):
        plot_and_save_patient_data(case_id, OUTPUT_DIR, pdf)

print(f"\nAll plots combined into: {combined_pdf_path}")
print(f"You can find individual vital files downloaded and removed in {OUTPUT_DIR} during processing.")
# Out:
# Processing Case 1...
# Successfully plotted and added Case 1 to PDF.
# Cleaned up '0001.vital'.
# Processing Case 2...
# Successfully plotted and added Case 2 to PDF.
# Cleaned up '0002.vital'.
# Processing Case 3...
# Successfully plotted and added Case 3 to PDF.
# Cleaned up '0003.vital'.
# Processing Case 4...
# Successfully plotted and added Case 4 to PDF.
# Cleaned up '0004.vital'.
# Processing Case 5...
# Successfully plotted and added Case 5 to PDF.
# Cleaned up '0005.vital'.
# Processing Case 6...
# Successfully plotted and added Case 6 to PDF.
# Cleaned up '0006.vital'.
# Processing Case 7...
# Successfully plotted and added Case 7 to PDF.
# Cleaned up '0007.vital'.
# Processing Case 8...
# Successfully plotted and added Case 8 to PDF.
# Cleaned up '0008.vital'.
# Processing Case 9...
# Successfully plotted and added Case 9 to PDF.
# Cleaned up '0009.vital'.
# Processing Case 10...
# Successfully plotted and added Case 10 to PDF.
# Cleaned up '0010.vital'.
# Processing Case 11...
# Successfully plotted and added Case 11 to PDF.
# Cleaned up '0011.vital'.
# Processing Case 12...
# Successfully plotted and added Case 12 to PDF.
# Cleaned up '0012.vital'.
# Processing Case 13...
# Successfully plotted and added Case 13 to PDF.
# Cleaned up '0013.vital'.
# Processing Case 14...
# Successfully plotted and added Case 14 to PDF.
# Cleaned up '0014.vital'.
# Processing Case 15...
# Successfully plotted and added Case 15 to PDF.
# Cleaned up '0015.vital'.
# Processing Case 16...
# Successfully plotted and added Case 16 to PDF.
# Cleaned up '0016.vital'.
# Processing Case 17...
# Successfully plotted and added Case 17 to PDF.
# Cleaned up '0017.vital'.
# Processing Case 18...
# Successfully plotted and added Case 18 to PDF.
# Cleaned up '0018.vital'.
# Processing Case 19...
# Successfully plotted and added Case 19 to PDF.
# Cleaned up '0019.vital'.
# Processing Case 20...
# Successfully plotted and added Case 20 to PDF.
# Cleaned up '0020.vital'.
# Processing Case 21...
# Successfully plotted and added Case 21 to PDF.
# Cleaned up '0021.vital'.
# Processing Case 22...
# Successfully plotted and added Case 22 to PDF.
# Cleaned up '0022.vital'.
# Processing Case 23...
# Successfully plotted and added Case 23 to PDF.
# Cleaned up '0023.vital'.
# Processing Case 24...
# Successfully plotted and added Case 24 to PDF.
# Cleaned up '0024.vital'.
# Processing Case 25...
# Successfully plotted and added Case 25 to PDF.
# Cleaned up '0025.vital'.
# Processing Case 26...
# Successfully plotted and added Case 26 to PDF.
# Cleaned up '0026.vital'.
# Processing Case 27...
# Successfully plotted and added Case 27 to PDF.
# Cleaned up '0027.vital'.
# Processing Case 28...
# Successfully plotted and added Case 28 to PDF.
# Cleaned up '0028.vital'.
# Processing Case 29...
# Successfully plotted and added Case 29 to PDF.
# Cleaned up '0029.vital'.
# Processing Case 30...
# Successfully plotted and added Case 30 to PDF.
# Cleaned up '0030.vital'.
# Processing Case 31...
# Successfully plotted and added Case 31 to PDF.
# Cleaned up '0031.vital'.
# Processing Case 32...
# Successfully plotted and added Case 32 to PDF.
# Cleaned up '0032.vital'.
# Processing Case 33...
# Successfully plotted and added Case 33 to PDF.
# Cleaned up '0033.vital'.
# Processing Case 34...
# Successfully plotted and added Case 34 to PDF.
# Cleaned up '0034.vital'.
# Processing Case 35...
# Successfully plotted and added Case 35 to PDF.
# Cleaned up '0035.vital'.
# Processing Case 36...
# Successfully plotted and added Case 36 to PDF.
# Cleaned up '0036.vital'.
# Processing Case 37...
# Successfully plotted and added Case 37 to PDF.
# Cleaned up '0037.vital'.
# Processing Case 38...
# Successfully plotted and added Case 38 to PDF.
# Cleaned up '0038.vital'.
# Processing Case 39...
# Successfully plotted and added Case 39 to PDF.
# Cleaned up '0039.vital'.
# Processing Case 40...
# Successfully plotted and added Case 40 to PDF.
# Cleaned up '0040.vital'.
# Processing Case 41...
# Successfully plotted and added Case 41 to PDF.
# Cleaned up '0041.vital'.
# Processing Case 42...
# Successfully plotted and added Case 42 to PDF.
# Cleaned up '0042.vital'.
# Processing Case 43...
# Successfully plotted and added Case 43 to PDF.
# Cleaned up '0043.vital'.
# Processing Case 44...
# Successfully plotted and added Case 44 to PDF.
# Cleaned up '0044.vital'.
# Processing Case 45...
# Successfully plotted and added Case 45 to PDF.
# Cleaned up '0045.vital'.
# Processing Case 46...
# Successfully plotted and added Case 46 to PDF.
# Cleaned up '0046.vital'.
# Processing Case 47...
# Successfully plotted and added Case 47 to PDF.
# Cleaned up '0047.vital'.
# Processing Case 48...
# Successfully plotted and added Case 48 to PDF.
# Cleaned up '0048.vital'.
# Processing Case 49...
# Successfully plotted and added Case 49 to PDF.
# Cleaned up '0049.vital'.
# Processing Case 50...
# Successfully plotted and added Case 50 to PDF.
# Cleaned up '0050.vital'.
# Processing Case 51...
# Successfully plotted and added Case 51 to PDF.
# Cleaned up '0051.vital'.
# Processing Case 52...
# Successfully plotted and added Case 52 to PDF.
# Cleaned up '0052.vital'.
# Processing Case 53...
# Successfully plotted and added Case 53 to PDF.
# Cleaned up '0053.vital'.
# Processing Case 54...
# Successfully plotted and added Case 54 to PDF.
# Cleaned up '0054.vital'.
# Processing Case 55...
# Successfully plotted and added Case 55 to PDF.
# Cleaned up '0055.vital'.
# Processing Case 56...
# Successfully plotted and added Case 56 to PDF.
# Cleaned up '0056.vital'.
# Processing Case 57...
# Successfully plotted and added Case 57 to PDF.
# Cleaned up '0057.vital'.
# Processing Case 58...
# Successfully plotted and added Case 58 to PDF.
# Cleaned up '0058.vital'.
# Processing Case 59...
# Successfully plotted and added Case 59 to PDF.
# Cleaned up '0059.vital'.
# Processing Case 60...
# Successfully plotted and added Case 60 to PDF.
# Cleaned up '0060.vital'.
# Processing Case 61...
# Successfully plotted and added Case 61 to PDF.
# Cleaned up '0061.vital'.
# Processing Case 62...
# Successfully plotted and added Case 62 to PDF.
# Cleaned up '0062.vital'.
# Processing Case 63...
# Successfully plotted and added Case 63 to PDF.
# Cleaned up '0063.vital'.
# Processing Case 64...
# Successfully plotted and added Case 64 to PDF.
# Cleaned up '0064.vital'.
# Processing Case 65...
# Successfully plotted and added Case 65 to PDF.
# Cleaned up '0065.vital'.
# Processing Case 66...
# Successfully plotted and added Case 66 to PDF.
# Cleaned up '0066.vital'.
# Processing Case 67...
# Successfully plotted and added Case 67 to PDF.
# Cleaned up '0067.vital'.
# Processing Case 68...
# Successfully plotted and added Case 68 to PDF.
# Cleaned up '0068.vital'.
# Processing Case 69...
# Successfully plotted and added Case 69 to PDF.
# Cleaned up '0069.vital'.
# Processing Case 70...
# Successfully plotted and added Case 70 to PDF.
# Cleaned up '0070.vital'.
# Processing Case 71...
# Successfully plotted and added Case 71 to PDF.
# Cleaned up '0071.vital'.
# Processing Case 72...
# Successfully plotted and added Case 72 to PDF.
# Cleaned up '0072.vital'.
# Processing Case 73...
# Successfully plotted and added Case 73 to PDF.
# Cleaned up '0073.vital'.
# Processing Case 74...
# Successfully plotted and added Case 74 to PDF.
# Cleaned up '0074.vital'.
# Processing Case 75...
# Successfully plotted and added Case 75 to PDF.
# Cleaned up '0075.vital'.
# Processing Case 76...
# Successfully plotted and added Case 76 to PDF.
# Cleaned up '0076.vital'.
# Processing Case 77...
# Successfully plotted and added Case 77 to PDF.
# Cleaned up '0077.vital'.
# Processing Case 78...
# Successfully plotted and added Case 78 to PDF.
# Cleaned up '0078.vital'.
# Processing Case 79...
# Successfully plotted and added Case 79 to PDF.
# Cleaned up '0079.vital'.
# Processing Case 80...
# Successfully plotted and added Case 80 to PDF.
# Cleaned up '0080.vital'.
# Processing Case 81...
# Successfully plotted and added Case 81 to PDF.
# Cleaned up '0081.vital'.
# Processing Case 82...
# Successfully plotted and added Case 82 to PDF.
# Cleaned up '0082.vital'.
# Processing Case 83...
# Successfully plotted and added Case 83 to PDF.
# Cleaned up '0083.vital'.
# Processing Case 84...
# Successfully plotted and added Case 84 to PDF.
# Cleaned up '0084.vital'.
# Processing Case 85...
# Successfully plotted and added Case 85 to PDF.
# Cleaned up '0085.vital'.
# Processing Case 86...
# Successfully plotted and added Case 86 to PDF.
# Cleaned up '0086.vital'.
# Processing Case 87...
# Successfully plotted and added Case 87 to PDF.
# Cleaned up '0087.vital'.
# Processing Case 88...
# Successfully plotted and added Case 88 to PDF.
# Cleaned up '0088.vital'.
# Processing Case 89...
# Successfully plotted and added Case 89 to PDF.
# Cleaned up '0089.vital'.
# Processing Case 90...
# Successfully plotted and added Case 90 to PDF.
# Cleaned up '0090.vital'.
# Processing Case 91...
# Successfully plotted and added Case 91 to PDF.
# Cleaned up '0091.vital'.
# Processing Case 92...
# Successfully plotted and added Case 92 to PDF.
# Cleaned up '0092.vital'.
# Processing Case 93...
# Successfully plotted and added Case 93 to PDF.
# Cleaned up '0093.vital'.
# Processing Case 94...
# Successfully plotted and added Case 94 to PDF.
# Cleaned up '0094.vital'.
# Processing Case 95...
# Successfully plotted and added Case 95 to PDF.
# Cleaned up '0095.vital'.
# Processing Case 96...
# Successfully plotted and added Case 96 to PDF.
# Cleaned up '0096.vital'.
# Processing Case 97...
# Successfully plotted and added Case 97 to PDF.
# Cleaned up '0097.vital'.
# Processing Case 98...
# Successfully plotted and added Case 98 to PDF.
# Cleaned up '0098.vital'.
# Processing Case 99...
# Successfully plotted and added Case 99 to PDF.
# Cleaned up '0099.vital'.
# Processing Case 100...
# Successfully plotted and added Case 100 to PDF.
# Cleaned up '0100.vital'.
#
# All plots combined into: patient_plots/all_patient_vitals_3_subplots.pdf
# You can find individual vital files downloaded and removed in patient_plots during processing.
