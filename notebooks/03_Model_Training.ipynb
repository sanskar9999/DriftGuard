# %% [markdown]
# Cell 1: Setup & Imports

# %%
import os

# 1. Define your source and destination directories
source_directory = '/kaggle/input/bis_transformer/transformers/default/1'
destination_directory = '/kaggle/working/'


for filename in os.listdir(source_directory):
    
    source_path = os.path.join(source_directory, filename)

    if os.path.isfile(source_path):
        destination_path = os.path.join(destination_directory, filename)

        try:

            with open(source_path, 'rb') as source_file:
                content = source_file.read()
            with open(destination_path, 'wb') as destination_file:
                destination_file.write(content)
        except Exception as e:
            print(f"Error copying {filename}: {e}")

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import joblib
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import glob

print("--- Libraries Imported ---v2")
# Out:
# 2025-07-23 12:13:40.966604: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753272821.223347      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753272821.303392      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# --- Libraries Imported ---v2

# %% [markdown]
# Cell 2: Configuration

# %%
# config

# input path
INPUT_DATA_DIR = '/kaggle/input/vitaldb-preprocessed-data' 
MASTER_DATASET_PATH = os.path.join(INPUT_DATA_DIR, 'vitaldb_master_dataset.parquet')

# output path
OUTPUT_DIR = '/kaggle/working/'
SCALER_PATH = os.path.join(OUTPUT_DIR, 'final_scaler.joblib')
X_TRAIN_PATH = os.path.join(OUTPUT_DIR, 'X_train.npy')
Y_TRAIN_PATH = os.path.join(OUTPUT_DIR, 'y_train.npy')
X_VAL_PATH = os.path.join(OUTPUT_DIR, 'X_val.npy')
Y_VAL_PATH = os.path.join(OUTPUT_DIR, 'y_val.npy')
MODEL_SAVE_PATH = os.path.join(OUTPUT_DIR, 'small_transformer_best_model.keras')

# training parameters
SEQUENCE_LENGTH = 300
BATCH_SIZE = 512
EPOCHS = 5
LEARNING_RATE = 1e-4
VALIDATION_SPLIT_SIZE = 0.10    # 90% data for training and 10% for testing  
RANDOM_SEED = 42

print("--- Configuration Set ---v2")
print(f"Scaler will be saved to: {SCALER_PATH}")
print(f"Sequences will be saved to: {OUTPUT_DIR}")
print(f"Best model will be saved to: {MODEL_SAVE_PATH}")
# Out:
# --- Configuration Set ---v2
# Scaler will be saved to: /kaggle/working/final_scaler.joblib
# Sequences will be saved to: /kaggle/working/
# Best model will be saved to: /kaggle/working/small_transformer_best_model.keras

# %% [markdown]
# Cell 3: Data Loading & Patient-Aware Splitting

# %%
print("--- Loading Master Dataset ---v2")
master_df = pd.read_parquet(MASTER_DATASET_PATH)

print(f"Loaded {len(master_df)} rows from {master_df['patient_id'].nunique()} patients.")

print("--- Performing Patient-Aware Split ---")
all_patient_ids = master_df['patient_id'].unique()

train_ids, val_ids = train_test_split(
    all_patient_ids,
    test_size=VALIDATION_SPLIT_SIZE,
    random_state=RANDOM_SEED
)

train_df = master_df[master_df['patient_id'].isin(train_ids)]
val_df = master_df[master_df['patient_id'].isin(val_ids)]

print(f"Training data: {len(train_df)} rows from {len(train_ids)} patients.")
print(f"Validation data: {len(val_df)} rows from {len(val_ids)} patients.")

del master_df
# Out:
# --- Loading Master Dataset ---v2
# Loaded 44988566 rows from 3237 patients.
# --- Performing Patient-Aware Split ---
# Training data: 40635720 rows from 2913 patients.
# Validation data: 4352846 rows from 324 patients.

# %% [markdown]
# Cell 4: Scaler Fitting (with Persistence)

# %%
feature_cols = ['Solar8000/HR', 'Solar8000/ART_MBP', 'Solar8000/PLETH_SPO2', 'Solar8000/ETCO2']

if os.path.exists(SCALER_PATH):
    print(f"--- Loading existing scaler from {SCALER_PATH} ---")
    scaler = joblib.load(SCALER_PATH)
else:
    print("--- Fitting new scaler ON TRAINING DATA ONLY ---v2")
    scaler = StandardScaler()
    scaler.fit(train_df[feature_cols])
    print(f"--- Saving scaler to {SCALER_PATH} ---")
    joblib.dump(scaler, SCALER_PATH)
# Out:
# --- Loading existing scaler from /kaggle/working/final_scaler.joblib ---

# %% [markdown]
# Cell 5: Sequence Generation

# %%
# --- Cell 5: High-Performance Ragged Tensor Pipeline (Pure Graph Windowing) ---

from tqdm.notebook import tqdm
import tensorflow as tf
import numpy as np

def calculate_steps_per_epoch(df, sequence_length, batch_size):
    """Calculates the number of steps per epoch."""
    total_sequences = 0
    grouped = df.groupby('patient_id')
    for _, group in tqdm(grouped, desc="Calculating total sequences", total=df['patient_id'].nunique()):
        if len(group) >= sequence_length:
            total_sequences += len(group) - sequence_length + 1
    steps = int(np.ceil(total_sequences / batch_size))
    return steps

def create_ragged_tensor_dataset(df, scaler, feature_cols, target_col, sequence_length, batch_size, shuffle=False):
    """
    The definitive high-performance pipeline.
    1. Manually constructs Ragged Tensors to avoid slow loading.
    2. Uses tf.signal.frame for pure, in-graph windowing, avoiding all sub-dataset overhead.
    """
    print(f"\n--- Building DEFINITIVE Ragged Tensor pipeline (shuffle={shuffle}) ---")
    df_scaled = df.copy()
    df_scaled[feature_cols] = scaler.transform(df[feature_cols])

    grouped = df_scaled.groupby('patient_id')
    all_patient_features = []
    all_patient_targets = []
    for _, group in tqdm(grouped, desc="Extracting patient data", total=df['patient_id'].nunique()):
        if len(group) < sequence_length:
            continue
        all_patient_features.append(group[feature_cols].values)
        all_patient_targets.append(group[target_col].values)

    print("--- Manually constructing Ragged Tensors ---")
    feature_values_list = [item for item in all_patient_features]
    target_values_list = [item for item in all_patient_targets]
    feature_row_splits = [0] + np.cumsum([len(p) for p in all_patient_features]).tolist()
    target_row_splits = [0] + np.cumsum([len(p) for p in all_patient_targets]).tolist()

    final_feature_values = np.concatenate(feature_values_list, axis=0).astype(np.float32)
    final_target_values = np.concatenate(target_values_list, axis=0).astype(np.float32)

    ragged_features = tf.RaggedTensor.from_row_splits(values=final_feature_values, row_splits=feature_row_splits)
    ragged_targets = tf.RaggedTensor.from_row_splits(values=final_target_values, row_splits=target_row_splits)

    dataset = tf.data.Dataset.from_tensor_slices((ragged_features, ragged_targets))

    # --- THE DEFINITIVE FIX: Pure Tensor-based windowing ---
    def create_sequences_from_tensors(features, targets):
        # Use tf.signal.frame to create windows directly from tensors. This is a single, fast C++ op.
        feature_sequences = tf.signal.frame(features, frame_length=sequence_length, frame_step=1, axis=0)

        # For targets, we need the value at the end of each sequence.
        # We can get this by windowing the 1D target tensor and taking the last element of each window.
        target_sequences = tf.signal.frame(targets, frame_length=sequence_length, frame_step=1, axis=0)
        target_labels = target_sequences[:, -1] # Take the last value of each sequence

        return tf.data.Dataset.from_tensor_slices((feature_sequences, target_labels))

    # flat_map now applies this highly efficient, pure-tensor function to each patient.
    dataset = dataset.flat_map(create_sequences_from_tensors)
    # --- END OF DEFINITIVE FIX ---

    if shuffle:
        dataset = dataset.shuffle(buffer_size=1024*4)

    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)

    return dataset

print("--- High-performance Ragged Tensor pipeline functions defined. ---v7 (Pure Graph Windowing)")
# Out:
# --- High-performance Ragged Tensor pipeline functions defined. ---v7 (Pure Graph Windowing)

# %% [markdown]
# Cell 6: Model Definition

# %%
# --- Cell 6: Model Definition & Simplified Callback ---

import json
import shutil
import os

# 1. SIMPLIFIED, ROBUST Resumable Checkpoint Callback
class ResumableCheckpoint(keras.callbacks.Callback):
    def __init__(self, filepath, state_filepath, save_freq, log_freq=500):
        super().__init__()
        self.filepath = filepath
        self.state_filepath = state_filepath
        self.save_freq = save_freq # How many batches between model saves
        self.log_freq = log_freq   # How many batches between log messages
        self.current_epoch = 0
        self.batches_seen_this_epoch = 0

    def on_epoch_begin(self, epoch, logs=None):
        # Store the current epoch (it's 0-indexed)
        self.current_epoch = epoch
        # Reset batch counter at the start of a new epoch
        self.batches_seen_this_epoch = 0

    def on_batch_end(self, batch, logs=None):
        # `batch` is the batch index within the current epoch
        self.batches_seen_this_epoch = batch + 1
        if self.batches_seen_this_epoch % self.log_freq == 0:
            loss = logs.get('loss', 'N/A'); mae = logs.get('mean_absolute_error', 'N/A')
            print(f"\n... Heartbeat: Reached Epoch {self.current_epoch + 1}, Batch {self.batches_seen_this_epoch}. Current loss: {loss:.4f}, MAE: {mae:.4f} ...")

        # Save a temporary model checkpoint periodically as a safeguard
        if self.batches_seen_this_epoch % self.save_freq == 0:
            print(f"\n--- Safeguard checkpoint: saving model at epoch {self.current_epoch + 1}, batch {self.batches_seen_this_epoch} ---")
            # Save to a temporary path to ensure atomicity
            root, ext = os.path.splitext(self.filepath)
            temp_filepath = root + '_temp' + ext
            self.model.save(temp_filepath)
            # Atomically move the file to the final destination
            shutil.move(temp_filepath, self.filepath)
            print("--- Safeguard checkpoint saved successfully. ---")

    def on_epoch_end(self, epoch, logs=None):
        """Saves the state to indicate that the next epoch should begin."""
        print(f"\n--- Epoch {epoch + 1} complete. Updating state file for resumption at Epoch {epoch + 2}. ---")
        # Save a state that indicates this epoch is done and the next one should start.
        # We use `epoch + 1` because the `epoch` argument is 0-indexed.
        state = {"epoch": epoch + 1}
        with open(self.state_filepath, 'w') as f:
            json.dump(state, f)
        print("--- State file updated for next epoch. ---")


# 2. Transformer Block Definition (Unchanged)
class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1, **kwargs):
        super().__init__(**kwargs)
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = keras.Sequential([layers.Dense(ff_dim, activation="gelu"), layers.Dense(embed_dim)])
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6); self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate); self.dropout2 = layers.Dropout(rate)
    def call(self, inputs, training=False):
        input_dtype = inputs.dtype; ln_input = self.layernorm1(inputs)
        attn_output = self.att(ln_input, ln_input)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = inputs + tf.cast(attn_output, dtype=input_dtype)
        ln_out1 = self.layernorm2(out1); ffn_output = self.ffn(ln_out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return out1 + tf.cast(ffn_output, dtype=input_dtype)

# 3. Model Builder (Unchanged)
def build_optimized_transformer_model(sequence_length, num_features):
    embed_dim=32; num_heads=4; ff_dim=128; num_blocks=2; dropout_rate=0.15
    print(f"\n--- Building OPTIMIZED model: embed_dim={embed_dim}, ff_dim={ff_dim}, num_heads={num_heads} ---")
    inputs = keras.Input(shape=(sequence_length, num_features)); x = layers.Dense(embed_dim)(inputs)
    for _ in range(num_blocks): x = TransformerBlock(embed_dim, num_heads, ff_dim, rate=dropout_rate)(x)
    x = layers.GlobalAveragePooling1D()(x); x = layers.Dropout(dropout_rate)(x)
    x = layers.Dense(16, activation="gelu")(x); outputs = layers.Dense(1, dtype='float32')(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    print(f"Model created with ~{model.count_params():,} parameters."); return model

print("--- Optimized model architecture and SIMPLIFIED ResumableCheckpoint defined ---v3")
# Out:
# --- Optimized model architecture and SIMPLIFIED ResumableCheckpoint defined ---v3

# %% [markdown]
# Cell 7: Training

# %%
# --- Cell 7: High-Performance & Resumable Training (Final Tuning) ---

RESUMABLE_MODEL_PATH = os.path.join(OUTPUT_DIR, 'resumable_checkpoint.keras')
STATE_FILE_PATH = os.path.join(OUTPUT_DIR, 'training_state.json')

# --- Step 1: Handle Resumption State ---
initial_epoch = 0
model = None # Initialize model as None

if os.path.exists(STATE_FILE_PATH) and os.path.exists(RESUMABLE_MODEL_PATH):
    print(f"--- Found existing checkpoint. Resuming training. ---")
    with open(STATE_FILE_PATH, 'r') as f:
        state = json.load(f)
    initial_epoch = state.get('epoch', 0)

    print(f"--- Resuming from epoch {initial_epoch + 1}. ---")
    model = keras.models.load_model(RESUMABLE_MODEL_PATH, custom_objects={"TransformerBlock": TransformerBlock})
else:
    print("--- No existing checkpoint found. Starting from scratch. ---")


# --- Step 2: Calculate Steps Per Epoch BEFORE creating datasets ---
# This is now CRITICAL for performance.
print("--- Pre-calculating steps per epoch for train and validation sets... ---")
train_steps = calculate_steps_per_epoch(train_df, SEQUENCE_LENGTH, BATCH_SIZE)
val_steps = calculate_steps_per_epoch(val_df, SEQUENCE_LENGTH, BATCH_SIZE)
print(f"--- Calculated {train_steps} train steps and {val_steps} validation steps per epoch. ---")


# --- Step 3: Create the Data Pipelines ---
print("\n--- Creating high-performance in-graph datasets... ---")
train_dataset = create_ragged_tensor_dataset(
    train_df, scaler, feature_cols, 'BIS/BIS', SEQUENCE_LENGTH, BATCH_SIZE, shuffle=True
)
val_dataset = create_ragged_tensor_dataset(
    val_df, scaler, feature_cols, 'BIS/BIS', SEQUENCE_LENGTH, BATCH_SIZE
)
print("\n--- tf.data in-graph pipelines created successfully. ---")
del train_df, val_df


# --- Step 4: Build Model if Needed ---
if model is None:
    print("--- Building new model from scratch. ---")
    model = build_optimized_transformer_model(SEQUENCE_LENGTH, len(feature_cols))


# --- Step 5: Compile and Train ---
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# Define LR schedule using the pre-calculated steps
total_steps_for_lr = train_steps * EPOCHS
warmup_steps = int(total_steps_for_lr * 0.1)
print(f"--- LR Schedule: Total Steps={total_steps_for_lr}, Warmup Steps={warmup_steps} ---")

lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay(
    initial_learning_rate=LEARNING_RATE,
    decay_steps=total_steps_for_lr - warmup_steps,
    end_learning_rate=0.0,
    power=1.0
)

optimizer = tf.keras.optimizers.AdamW(learning_rate=lr_schedule, weight_decay=0.01)
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])
model.summary()

# Define Callbacks
best_model_checkpoint = keras.callbacks.ModelCheckpoint(
    MODEL_SAVE_PATH, monitor='val_loss', save_best_only=True, mode='min', verbose=1
)
resumable_checkpoint = ResumableCheckpoint(
    filepath=RESUMABLE_MODEL_PATH, state_filepath=STATE_FILE_PATH, save_freq=2000, log_freq=500
)
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=2, restore_best_weights=True, verbose=1
)

print(f"\n--- Starting FULLY OPTIMIZED & RESUMABLE Training ---")
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCHS,
    callbacks=[best_model_checkpoint, resumable_checkpoint, early_stopping],
    initial_epoch=initial_epoch,
    steps_per_epoch=train_steps,       # <-- CRITICAL FIX
    validation_steps=val_steps         # <-- CRITICAL FIX
)
# Out:
# --- No existing checkpoint found. Starting from scratch. ---
# --- Pre-calculating steps per epoch for train and validation sets... ---
# Calculating total sequences:   0%|          | 0/2913 [00:00<?, ?it/s]
# Calculating total sequences:   0%|          | 0/324 [00:00<?, ?it/s]
# --- Calculated 77666 train steps and 8313 validation steps per epoch. ---
#
# --- Creating high-performance in-graph datasets... ---
#
# --- Building DEFINITIVE Ragged Tensor pipeline (shuffle=True) ---
# Extracting patient data:   0%|          | 0/2913 [00:00<?, ?it/s]
# --- Manually constructing Ragged Tensors ---
# I0000 00:00:1753272852.554493      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# --- Building DEFINITIVE Ragged Tensor pipeline (shuffle=False) ---
# Extracting patient data:   0%|          | 0/324 [00:00<?, ?it/s]
# --- Manually constructing Ragged Tensors ---
#
# --- tf.data in-graph pipelines created successfully. ---
# --- Building new model from scratch. ---
#
# --- Building OPTIMIZED model: embed_dim=32, ff_dim=128, num_heads=4 ---
# Model created with ~51,265 parameters.
# --- LR Schedule: Total Steps=388330, Warmup Steps=38833 ---
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 300, 4)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 300, 32)        │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block               │ (None, 300, 32)        │        25,280 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_1             │ (None, 300, 32)        │        25,280 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 32)             │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51,265 (200.25 KB)
#  Trainable params: 51,265 (200.25 KB)
#  Non-trainable params: 0 (0.00 B)
# --- Starting FULLY OPTIMIZED & RESUMABLE Training ---
# Epoch 1/5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753272869.488497      63 service.cc:148] XLA service 0x78e76800abe0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753272869.489371      63 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1753272870.489421      63 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1753272876.368184      63 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#   499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:59:16 93ms/step - loss: 1361.9092 - mean_absolute_error: 33.2654
# ... Heartbeat: Reached Epoch 1, Batch 500. Current loss: 891.0670, MAE: 24.4528 ...
#   999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:58:22 93ms/step - loss: 1020.4475 - mean_absolute_error: 26.5803
# ... Heartbeat: Reached Epoch 1, Batch 1000. Current loss: 560.5881, MAE: 17.3811 ...
#  1499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:57:32 93ms/step - loss: 847.1587 - mean_absolute_error: 23.0600
# ... Heartbeat: Reached Epoch 1, Batch 1500. Current loss: 450.2608, MAE: 14.8859 ...
#  1999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:56:45 93ms/step - loss: 741.8104 - mean_absolute_error: 20.9281
# ... Heartbeat: Reached Epoch 1, Batch 2000. Current loss: 401.5424, MAE: 14.0638 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 2000 ---
# --- Safeguard checkpoint saved successfully. ---
#  2499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:56:02 93ms/step - loss: 669.9583 - mean_absolute_error: 19.4794
# ... Heartbeat: Reached Epoch 1, Batch 2500. Current loss: 365.1631, MAE: 13.3059 ...
#  2999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:55:15 93ms/step - loss: 616.5180 - mean_absolute_error: 18.3860
# ... Heartbeat: Reached Epoch 1, Batch 3000. Current loss: 335.5060, MAE: 12.5901 ...
#  3499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:54:28 93ms/step - loss: 574.7490 - mean_absolute_error: 17.5256
# ... Heartbeat: Reached Epoch 1, Batch 3500. Current loss: 317.2727, MAE: 12.2354 ...
#  3999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:53:41 93ms/step - loss: 541.9480 - mean_absolute_error: 16.8503
# ... Heartbeat: Reached Epoch 1, Batch 4000. Current loss: 306.6336, MAE: 11.9800 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 4000 ---
# --- Safeguard checkpoint saved successfully. ---
#  4499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:52:55 93ms/step - loss: 515.0885 - mean_absolute_error: 16.2941
# ... Heartbeat: Reached Epoch 1, Batch 4500. Current loss: 294.5760, MAE: 11.7225 ...
#  4999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:52:08 93ms/step - loss: 492.4335 - mean_absolute_error: 15.8209
# ... Heartbeat: Reached Epoch 1, Batch 5000. Current loss: 284.2404, MAE: 11.4584 ...
#  5499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:51:20 93ms/step - loss: 473.2170 - mean_absolute_error: 15.4177
# ... Heartbeat: Reached Epoch 1, Batch 5500. Current loss: 278.1101, MAE: 11.3131 ...
#  5999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:50:34 93ms/step - loss: 456.5844 - mean_absolute_error: 15.0684
# ... Heartbeat: Reached Epoch 1, Batch 6000. Current loss: 270.7740, MAE: 11.1689 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 6000 ---
# --- Safeguard checkpoint saved successfully. ---
#  6499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:49:48 93ms/step - loss: 441.9661 - mean_absolute_error: 14.7600
# ... Heartbeat: Reached Epoch 1, Batch 6500. Current loss: 263.0794, MAE: 10.9763 ...
#  6999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:49:01 93ms/step - loss: 429.1125 - mean_absolute_error: 14.4871
# ... Heartbeat: Reached Epoch 1, Batch 7000. Current loss: 260.0549, MAE: 10.9033 ...
#  7499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:48:14 93ms/step - loss: 417.6827 - mean_absolute_error: 14.2451
# ... Heartbeat: Reached Epoch 1, Batch 7500. Current loss: 255.9056, MAE: 10.8325 ...
#  7999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:47:28 93ms/step - loss: 407.3513 - mean_absolute_error: 14.0262
# ... Heartbeat: Reached Epoch 1, Batch 8000. Current loss: 249.6897, MAE: 10.6706 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 8000 ---
# --- Safeguard checkpoint saved successfully. ---
#  8499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:46:42 93ms/step - loss: 397.9437 - mean_absolute_error: 13.8268
# ... Heartbeat: Reached Epoch 1, Batch 8500. Current loss: 244.7940, MAE: 10.5735 ...
#  8999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:45:56 93ms/step - loss: 389.3233 - mean_absolute_error: 13.6422
# ... Heartbeat: Reached Epoch 1, Batch 9000. Current loss: 241.0973, MAE: 10.4505 ...
#  9499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:45:09 93ms/step - loss: 381.5029 - mean_absolute_error: 13.4748
# ... Heartbeat: Reached Epoch 1, Batch 9500. Current loss: 240.1173, MAE: 10.4523 ...
#  9999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:44:23 93ms/step - loss: 374.3541 - mean_absolute_error: 13.3216
# ... Heartbeat: Reached Epoch 1, Batch 10000. Current loss: 236.8255, MAE: 10.3754 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 10000 ---
# --- Safeguard checkpoint saved successfully. ---
# 10499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:43:37 93ms/step - loss: 367.7650 - mean_absolute_error: 13.1802
# ... Heartbeat: Reached Epoch 1, Batch 10500. Current loss: 234.5460, MAE: 10.3212 ...
# 10999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:42:50 93ms/step - loss: 361.6637 - mean_absolute_error: 13.0492
# ... Heartbeat: Reached Epoch 1, Batch 11000. Current loss: 234.0565, MAE: 10.3045 ...
# 11499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:42:04 93ms/step - loss: 356.0953 - mean_absolute_error: 12.9300
# ... Heartbeat: Reached Epoch 1, Batch 11500. Current loss: 233.0432, MAE: 10.2969 ...
# 11999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:41:17 93ms/step - loss: 350.9541 - mean_absolute_error: 12.8204
# ... Heartbeat: Reached Epoch 1, Batch 12000. Current loss: 232.5539, MAE: 10.3050 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 12000 ---
# --- Safeguard checkpoint saved successfully. ---
# 12499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:40:32 93ms/step - loss: 346.1751 - mean_absolute_error: 12.7185
# ... Heartbeat: Reached Epoch 1, Batch 12500. Current loss: 230.1293, MAE: 10.2424 ...
# 12999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:39:45 93ms/step - loss: 341.7111 - mean_absolute_error: 12.6232
# ... Heartbeat: Reached Epoch 1, Batch 13000. Current loss: 230.3064, MAE: 10.2487 ...
# 13499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:38:59 93ms/step - loss: 337.5999 - mean_absolute_error: 12.5363
# ... Heartbeat: Reached Epoch 1, Batch 13500. Current loss: 231.3309, MAE: 10.2987 ...
# 13999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:38:12 93ms/step - loss: 333.7741 - mean_absolute_error: 12.4557
# ... Heartbeat: Reached Epoch 1, Batch 14000. Current loss: 229.9630, MAE: 10.2684 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 14000 ---
# --- Safeguard checkpoint saved successfully. ---
# 14499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:37:26 93ms/step - loss: 330.1743 - mean_absolute_error: 12.3800
# ... Heartbeat: Reached Epoch 1, Batch 14500. Current loss: 228.4816, MAE: 10.2339 ...
# 14999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:36:40 93ms/step - loss: 326.7591 - mean_absolute_error: 12.3079
# ... Heartbeat: Reached Epoch 1, Batch 15000. Current loss: 227.0043, MAE: 10.2024 ...
# 15499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:35:53 93ms/step - loss: 323.5234 - mean_absolute_error: 12.2395
# ... Heartbeat: Reached Epoch 1, Batch 15500. Current loss: 225.5332, MAE: 10.1646 ...
# 15999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:35:07 93ms/step - loss: 320.4382 - mean_absolute_error: 12.1743
# ... Heartbeat: Reached Epoch 1, Batch 16000. Current loss: 224.0296, MAE: 10.1307 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 16000 ---
# --- Safeguard checkpoint saved successfully. ---
# 16499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:34:21 93ms/step - loss: 317.4958 - mean_absolute_error: 12.1119
# ... Heartbeat: Reached Epoch 1, Batch 16500. Current loss: 222.3428, MAE: 10.0910 ...
# 16999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:33:35 93ms/step - loss: 314.6916 - mean_absolute_error: 12.0524
# ... Heartbeat: Reached Epoch 1, Batch 17000. Current loss: 222.1347, MAE: 10.0922 ...
# 17499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:32:48 93ms/step - loss: 312.0108 - mean_absolute_error: 11.9953
# ... Heartbeat: Reached Epoch 1, Batch 17500. Current loss: 220.0604, MAE: 10.0340 ...
# 17999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:32:02 93ms/step - loss: 309.4475 - mean_absolute_error: 11.9404
# ... Heartbeat: Reached Epoch 1, Batch 18000. Current loss: 220.6177, MAE: 10.0378 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 18000 ---
# --- Safeguard checkpoint saved successfully. ---
# 18499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:31:16 93ms/step - loss: 307.0213 - mean_absolute_error: 11.8885
# ... Heartbeat: Reached Epoch 1, Batch 18500. Current loss: 218.8779, MAE: 9.9951 ...
# 18999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:30:30 93ms/step - loss: 304.6840 - mean_absolute_error: 11.8381
# ... Heartbeat: Reached Epoch 1, Batch 19000. Current loss: 217.4579, MAE: 9.9567 ...
# 19499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:29:43 93ms/step - loss: 302.4185 - mean_absolute_error: 11.7890
# ... Heartbeat: Reached Epoch 1, Batch 19500. Current loss: 215.8361, MAE: 9.9101 ...
# 19999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:28:57 93ms/step - loss: 300.2440 - mean_absolute_error: 11.7419
# ... Heartbeat: Reached Epoch 1, Batch 20000. Current loss: 214.9902, MAE: 9.8945 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 20000 ---
# --- Safeguard checkpoint saved successfully. ---
# 20499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:28:11 93ms/step - loss: 298.1580 - mean_absolute_error: 11.6968
# ... Heartbeat: Reached Epoch 1, Batch 20500. Current loss: 214.1698, MAE: 9.8787 ...
# 20999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:27:25 93ms/step - loss: 296.1692 - mean_absolute_error: 11.6540
# ... Heartbeat: Reached Epoch 1, Batch 21000. Current loss: 215.1932, MAE: 9.9207 ...
# 21499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:26:38 93ms/step - loss: 294.2754 - mean_absolute_error: 11.6133
# ... Heartbeat: Reached Epoch 1, Batch 21500. Current loss: 214.2594, MAE: 9.8911 ...
# 21999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:25:52 93ms/step - loss: 292.4485 - mean_absolute_error: 11.5740
# ... Heartbeat: Reached Epoch 1, Batch 22000. Current loss: 213.3978, MAE: 9.8732 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 22000 ---
# --- Safeguard checkpoint saved successfully. ---
# 22499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:25:06 93ms/step - loss: 290.6808 - mean_absolute_error: 11.5360
# ... Heartbeat: Reached Epoch 1, Batch 22500. Current loss: 212.4740, MAE: 9.8489 ...
# 22999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:24:20 93ms/step - loss: 288.9732 - mean_absolute_error: 11.4992
# ... Heartbeat: Reached Epoch 1, Batch 23000. Current loss: 211.8797, MAE: 9.8413 ...
# 23499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:23:34 93ms/step - loss: 287.3243 - mean_absolute_error: 11.4637
# ... Heartbeat: Reached Epoch 1, Batch 23500. Current loss: 211.1812, MAE: 9.8178 ...
# 23999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:22:47 93ms/step - loss: 285.7401 - mean_absolute_error: 11.4294
# ... Heartbeat: Reached Epoch 1, Batch 24000. Current loss: 211.2054, MAE: 9.8203 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 24000 ---
# --- Safeguard checkpoint saved successfully. ---
# 24499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:22:01 93ms/step - loss: 284.2218 - mean_absolute_error: 11.3968
# ... Heartbeat: Reached Epoch 1, Batch 24500. Current loss: 211.2016, MAE: 9.8282 ...
# 24999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:21:15 93ms/step - loss: 282.7566 - mean_absolute_error: 11.3652
# ... Heartbeat: Reached Epoch 1, Batch 25000. Current loss: 210.8717, MAE: 9.8141 ...
# 25499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:20:28 93ms/step - loss: 281.3515 - mean_absolute_error: 11.3350
# ... Heartbeat: Reached Epoch 1, Batch 25500. Current loss: 211.5832, MAE: 9.8327 ...
# 25999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:19:42 93ms/step - loss: 280.0051 - mean_absolute_error: 11.3060
# ... Heartbeat: Reached Epoch 1, Batch 26000. Current loss: 210.8569, MAE: 9.8141 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 26000 ---
# --- Safeguard checkpoint saved successfully. ---
# 26499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:18:56 93ms/step - loss: 278.6872 - mean_absolute_error: 11.2775
# ... Heartbeat: Reached Epoch 1, Batch 26500. Current loss: 210.1581, MAE: 9.7983 ...
# 26999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:18:10 93ms/step - loss: 277.4163 - mean_absolute_error: 11.2500
# ... Heartbeat: Reached Epoch 1, Batch 27000. Current loss: 209.8531, MAE: 9.7896 ...
# 27499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:17:23 93ms/step - loss: 276.1821 - mean_absolute_error: 11.2233
# ... Heartbeat: Reached Epoch 1, Batch 27500. Current loss: 209.0428, MAE: 9.7651 ...
# 27999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:16:37 93ms/step - loss: 274.9773 - mean_absolute_error: 11.1970
# ... Heartbeat: Reached Epoch 1, Batch 28000. Current loss: 208.5821, MAE: 9.7420 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 28000 ---
# --- Safeguard checkpoint saved successfully. ---
# 28499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:15:51 93ms/step - loss: 273.8100 - mean_absolute_error: 11.1715
# ... Heartbeat: Reached Epoch 1, Batch 28500. Current loss: 208.3282, MAE: 9.7447 ...
# 28999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:15:05 93ms/step - loss: 272.6825 - mean_absolute_error: 11.1470
# ... Heartbeat: Reached Epoch 1, Batch 29000. Current loss: 208.9067, MAE: 9.7703 ...
# 29499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:14:18 93ms/step - loss: 271.5982 - mean_absolute_error: 11.1236
# ... Heartbeat: Reached Epoch 1, Batch 29500. Current loss: 208.2905, MAE: 9.7533 ...
# 29999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:13:32 93ms/step - loss: 270.5381 - mean_absolute_error: 11.1006
# ... Heartbeat: Reached Epoch 1, Batch 30000. Current loss: 208.3254, MAE: 9.7662 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 30000 ---
# --- Safeguard checkpoint saved successfully. ---
# 30499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:12:46 93ms/step - loss: 269.5182 - mean_absolute_error: 11.0788
# ... Heartbeat: Reached Epoch 1, Batch 30500. Current loss: 208.2264, MAE: 9.7638 ...
# 30999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:12:00 93ms/step - loss: 268.5308 - mean_absolute_error: 11.0576
# ... Heartbeat: Reached Epoch 1, Batch 31000. Current loss: 208.2744, MAE: 9.7635 ...
# 31499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:11:13 93ms/step - loss: 267.5702 - mean_absolute_error: 11.0369
# ... Heartbeat: Reached Epoch 1, Batch 31500. Current loss: 207.8921, MAE: 9.7558 ...
# 31999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:10:27 93ms/step - loss: 266.6421 - mean_absolute_error: 11.0170
# ... Heartbeat: Reached Epoch 1, Batch 32000. Current loss: 208.2882, MAE: 9.7638 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 32000 ---
# --- Safeguard checkpoint saved successfully. ---
# 32499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:09:41 93ms/step - loss: 265.7400 - mean_absolute_error: 10.9976
# ... Heartbeat: Reached Epoch 1, Batch 32500. Current loss: 207.4215, MAE: 9.7377 ...
# 32999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:08:54 93ms/step - loss: 264.8555 - mean_absolute_error: 10.9785
# ... Heartbeat: Reached Epoch 1, Batch 33000. Current loss: 207.1758, MAE: 9.7373 ...
# 33499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:08:08 93ms/step - loss: 263.9892 - mean_absolute_error: 10.9599
# ... Heartbeat: Reached Epoch 1, Batch 33500. Current loss: 206.4589, MAE: 9.7181 ...
# 33999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:07:22 93ms/step - loss: 263.1384 - mean_absolute_error: 10.9415
# ... Heartbeat: Reached Epoch 1, Batch 34000. Current loss: 205.9437, MAE: 9.7092 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 34000 ---
# --- Safeguard checkpoint saved successfully. ---
# 34499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:06:35 93ms/step - loss: 262.3092 - mean_absolute_error: 10.9236
# ... Heartbeat: Reached Epoch 1, Batch 34500. Current loss: 205.8262, MAE: 9.7025 ...
# 34999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:05:49 93ms/step - loss: 261.4967 - mean_absolute_error: 10.9061
# ... Heartbeat: Reached Epoch 1, Batch 35000. Current loss: 205.0724, MAE: 9.6860 ...
# 35499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:05:03 93ms/step - loss: 260.7014 - mean_absolute_error: 10.8889
# ... Heartbeat: Reached Epoch 1, Batch 35500. Current loss: 204.9447, MAE: 9.6862 ...
# 35999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:04:16 93ms/step - loss: 259.9296 - mean_absolute_error: 10.8723
# ... Heartbeat: Reached Epoch 1, Batch 36000. Current loss: 205.2448, MAE: 9.6984 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 36000 ---
# --- Safeguard checkpoint saved successfully. ---
# 36499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:03:30 93ms/step - loss: 259.1788 - mean_absolute_error: 10.8562
# ... Heartbeat: Reached Epoch 1, Batch 36500. Current loss: 204.9852, MAE: 9.6957 ...
# 36999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:02:44 93ms/step - loss: 258.4502 - mean_absolute_error: 10.8406
# ... Heartbeat: Reached Epoch 1, Batch 37000. Current loss: 205.3125, MAE: 9.7030 ...
# 37499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:01:58 93ms/step - loss: 257.7368 - mean_absolute_error: 10.8253
# ... Heartbeat: Reached Epoch 1, Batch 37500. Current loss: 204.7224, MAE: 9.6916 ...
# 37999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:01:11 93ms/step - loss: 257.0343 - mean_absolute_error: 10.8102
# ... Heartbeat: Reached Epoch 1, Batch 38000. Current loss: 203.9046, MAE: 9.6660 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 38000 ---
# --- Safeguard checkpoint saved successfully. ---
# 38499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:00:25 93ms/step - loss: 256.3436 - mean_absolute_error: 10.7953
# ... Heartbeat: Reached Epoch 1, Batch 38500. Current loss: 203.5327, MAE: 9.6553 ...
# 38999/77666 ━━━━━━━━━━━━━━━━━━━━ 59:39 93ms/step - loss: 255.6660 - mean_absolute_error: 10.7807
# ... Heartbeat: Reached Epoch 1, Batch 39000. Current loss: 203.4182, MAE: 9.6563 ...
# 39499/77666 ━━━━━━━━━━━━━━━━━━━━ 58:53 93ms/step - loss: 255.0020 - mean_absolute_error: 10.7664
# ... Heartbeat: Reached Epoch 1, Batch 39500. Current loss: 202.7562, MAE: 9.6401 ...
# 39999/77666 ━━━━━━━━━━━━━━━━━━━━ 58:06 93ms/step - loss: 254.3503 - mean_absolute_error: 10.7524
# ... Heartbeat: Reached Epoch 1, Batch 40000. Current loss: 202.9180, MAE: 9.6467 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 40000 ---
# --- Safeguard checkpoint saved successfully. ---
# 40499/77666 ━━━━━━━━━━━━━━━━━━━━ 57:20 93ms/step - loss: 253.7121 - mean_absolute_error: 10.7386
# ... Heartbeat: Reached Epoch 1, Batch 40500. Current loss: 202.3794, MAE: 9.6331 ...
# 40999/77666 ━━━━━━━━━━━━━━━━━━━━ 56:34 93ms/step - loss: 253.0881 - mean_absolute_error: 10.7251
# ... Heartbeat: Reached Epoch 1, Batch 41000. Current loss: 202.5084, MAE: 9.6276 ...
# 41499/77666 ━━━━━━━━━━━━━━━━━━━━ 55:48 93ms/step - loss: 252.4760 - mean_absolute_error: 10.7119
# ... Heartbeat: Reached Epoch 1, Batch 41500. Current loss: 202.1756, MAE: 9.6223 ...
# 41999/77666 ━━━━━━━━━━━━━━━━━━━━ 55:01 93ms/step - loss: 251.8793 - mean_absolute_error: 10.6990
# ... Heartbeat: Reached Epoch 1, Batch 42000. Current loss: 202.2134, MAE: 9.6265 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 42000 ---
# --- Safeguard checkpoint saved successfully. ---
# 42499/77666 ━━━━━━━━━━━━━━━━━━━━ 54:15 93ms/step - loss: 251.2933 - mean_absolute_error: 10.6863
# ... Heartbeat: Reached Epoch 1, Batch 42500. Current loss: 202.1192, MAE: 9.6238 ...
# 42999/77666 ━━━━━━━━━━━━━━━━━━━━ 53:29 93ms/step - loss: 250.7232 - mean_absolute_error: 10.6741
# ... Heartbeat: Reached Epoch 1, Batch 43000. Current loss: 202.0952, MAE: 9.6305 ...
# 43499/77666 ━━━━━━━━━━━━━━━━━━━━ 52:42 93ms/step - loss: 250.1617 - mean_absolute_error: 10.6620
# ... Heartbeat: Reached Epoch 1, Batch 43500. Current loss: 201.5663, MAE: 9.6207 ...
# 43999/77666 ━━━━━━━━━━━━━━━━━━━━ 51:56 93ms/step - loss: 249.6042 - mean_absolute_error: 10.6501
# ... Heartbeat: Reached Epoch 1, Batch 44000. Current loss: 200.8771, MAE: 9.6019 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 44000 ---
# --- Safeguard checkpoint saved successfully. ---
# 44499/77666 ━━━━━━━━━━━━━━━━━━━━ 51:10 93ms/step - loss: 249.0579 - mean_absolute_error: 10.6383
# ... Heartbeat: Reached Epoch 1, Batch 44500. Current loss: 200.9354, MAE: 9.6034 ...
# 44999/77666 ━━━━━━━━━━━━━━━━━━━━ 50:24 93ms/step - loss: 248.5211 - mean_absolute_error: 10.6267
# ... Heartbeat: Reached Epoch 1, Batch 45000. Current loss: 200.5129, MAE: 9.5831 ...
# 45499/77666 ━━━━━━━━━━━━━━━━━━━━ 49:38 93ms/step - loss: 247.9926 - mean_absolute_error: 10.6153
# ... Heartbeat: Reached Epoch 1, Batch 45500. Current loss: 200.5172, MAE: 9.5865 ...
# 45999/77666 ━━━━━━━━━━━━━━━━━━━━ 48:52 93ms/step - loss: 247.4754 - mean_absolute_error: 10.6040
# ... Heartbeat: Reached Epoch 1, Batch 46000. Current loss: 200.2061, MAE: 9.5753 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 46000 ---
# --- Safeguard checkpoint saved successfully. ---
# 46499/77666 ━━━━━━━━━━━━━━━━━━━━ 48:05 93ms/step - loss: 246.9651 - mean_absolute_error: 10.5929
# ... Heartbeat: Reached Epoch 1, Batch 46500. Current loss: 199.8721, MAE: 9.5665 ...
# 46999/77666 ━━━━━━━━━━━━━━━━━━━━ 47:19 93ms/step - loss: 246.4637 - mean_absolute_error: 10.5820
# ... Heartbeat: Reached Epoch 1, Batch 47000. Current loss: 199.6773, MAE: 9.5619 ...
# 47499/77666 ━━━━━━━━━━━━━━━━━━━━ 46:33 93ms/step - loss: 245.9704 - mean_absolute_error: 10.5712
# ... Heartbeat: Reached Epoch 1, Batch 47500. Current loss: 199.4726, MAE: 9.5577 ...
# 47999/77666 ━━━━━━━━━━━━━━━━━━━━ 45:47 93ms/step - loss: 245.4833 - mean_absolute_error: 10.5606
# ... Heartbeat: Reached Epoch 1, Batch 48000. Current loss: 198.9358, MAE: 9.5448 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 48000 ---
# --- Safeguard checkpoint saved successfully. ---
# 48499/77666 ━━━━━━━━━━━━━━━━━━━━ 45:01 93ms/step - loss: 245.0015 - mean_absolute_error: 10.5501
# ... Heartbeat: Reached Epoch 1, Batch 48500. Current loss: 198.6815, MAE: 9.5405 ...
# 48999/77666 ━━━━━━━━━━━━━━━━━━━━ 44:14 93ms/step - loss: 244.5291 - mean_absolute_error: 10.5398
# ... Heartbeat: Reached Epoch 1, Batch 49000. Current loss: 198.6194, MAE: 9.5392 ...
# 49499/77666 ━━━━━━━━━━━━━━━━━━━━ 43:28 93ms/step - loss: 244.0633 - mean_absolute_error: 10.5296
# ... Heartbeat: Reached Epoch 1, Batch 49500. Current loss: 198.3524, MAE: 9.5305 ...
# 49999/77666 ━━━━━━━━━━━━━━━━━━━━ 42:42 93ms/step - loss: 243.6063 - mean_absolute_error: 10.5196
# ... Heartbeat: Reached Epoch 1, Batch 50000. Current loss: 198.2016, MAE: 9.5237 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 50000 ---
# --- Safeguard checkpoint saved successfully. ---
# 50499/77666 ━━━━━━━━━━━━━━━━━━━━ 41:56 93ms/step - loss: 243.1575 - mean_absolute_error: 10.5098
# ... Heartbeat: Reached Epoch 1, Batch 50500. Current loss: 198.2081, MAE: 9.5248 ...
# 50999/77666 ━━━━━━━━━━━━━━━━━━━━ 41:10 93ms/step - loss: 242.7155 - mean_absolute_error: 10.5001
# ... Heartbeat: Reached Epoch 1, Batch 51000. Current loss: 197.8570, MAE: 9.5124 ...
# 51499/77666 ━━━━━━━━━━━━━━━━━━━━ 40:23 93ms/step - loss: 242.2809 - mean_absolute_error: 10.4905
# ... Heartbeat: Reached Epoch 1, Batch 51500. Current loss: 197.6548, MAE: 9.5044 ...
# 51999/77666 ━━━━━━━━━━━━━━━━━━━━ 39:37 93ms/step - loss: 241.8493 - mean_absolute_error: 10.4810
# ... Heartbeat: Reached Epoch 1, Batch 52000. Current loss: 197.1603, MAE: 9.4915 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 52000 ---
# --- Safeguard checkpoint saved successfully. ---
# 52499/77666 ━━━━━━━━━━━━━━━━━━━━ 38:51 93ms/step - loss: 241.4217 - mean_absolute_error: 10.4715
# ... Heartbeat: Reached Epoch 1, Batch 52500. Current loss: 196.9872, MAE: 9.4869 ...
# 52999/77666 ━━━━━━━━━━━━━━━━━━━━ 38:05 93ms/step - loss: 241.0049 - mean_absolute_error: 10.4623
# ... Heartbeat: Reached Epoch 1, Batch 53000. Current loss: 197.4369, MAE: 9.5011 ...
# 53499/77666 ━━━━━━━━━━━━━━━━━━━━ 37:18 93ms/step - loss: 240.5980 - mean_absolute_error: 10.4533
# ... Heartbeat: Reached Epoch 1, Batch 53500. Current loss: 197.4660, MAE: 9.5031 ...
# 53999/77666 ━━━━━━━━━━━━━━━━━━━━ 36:32 93ms/step - loss: 240.1968 - mean_absolute_error: 10.4444
# ... Heartbeat: Reached Epoch 1, Batch 54000. Current loss: 197.0192, MAE: 9.4873 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 54000 ---
# --- Safeguard checkpoint saved successfully. ---
# 54499/77666 ━━━━━━━━━━━━━━━━━━━━ 35:46 93ms/step - loss: 239.8007 - mean_absolute_error: 10.4356
# ... Heartbeat: Reached Epoch 1, Batch 54500. Current loss: 197.0608, MAE: 9.4845 ...
# 54999/77666 ━━━━━━━━━━━━━━━━━━━━ 35:00 93ms/step - loss: 239.4104 - mean_absolute_error: 10.4270
# ... Heartbeat: Reached Epoch 1, Batch 55000. Current loss: 196.8559, MAE: 9.4811 ...
# 55499/77666 ━━━━━━━━━━━━━━━━━━━━ 34:13 93ms/step - loss: 239.0248 - mean_absolute_error: 10.4184
# ... Heartbeat: Reached Epoch 1, Batch 55500. Current loss: 196.3918, MAE: 9.4665 ...
# 55999/77666 ━━━━━━━━━━━━━━━━━━━━ 33:27 93ms/step - loss: 238.6436 - mean_absolute_error: 10.4098
# ... Heartbeat: Reached Epoch 1, Batch 56000. Current loss: 196.2139, MAE: 9.4605 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 56000 ---
# --- Safeguard checkpoint saved successfully. ---
# 56499/77666 ━━━━━━━━━━━━━━━━━━━━ 32:41 93ms/step - loss: 238.2657 - mean_absolute_error: 10.4014
# ... Heartbeat: Reached Epoch 1, Batch 56500. Current loss: 195.6792, MAE: 9.4475 ...
# 56999/77666 ━━━━━━━━━━━━━━━━━━━━ 31:55 93ms/step - loss: 237.8929 - mean_absolute_error: 10.3931
# ... Heartbeat: Reached Epoch 1, Batch 57000. Current loss: 195.9359, MAE: 9.4557 ...
# 57499/77666 ━━━━━━━━━━━━━━━━━━━━ 31:08 93ms/step - loss: 237.5267 - mean_absolute_error: 10.3849
# ... Heartbeat: Reached Epoch 1, Batch 57500. Current loss: 195.8380, MAE: 9.4517 ...
# 57999/77666 ━━━━━━━━━━━━━━━━━━━━ 30:22 93ms/step - loss: 237.1679 - mean_absolute_error: 10.3769
# ... Heartbeat: Reached Epoch 1, Batch 58000. Current loss: 196.0296, MAE: 9.4637 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 58000 ---
# --- Safeguard checkpoint saved successfully. ---
# 58499/77666 ━━━━━━━━━━━━━━━━━━━━ 29:36 93ms/step - loss: 236.8163 - mean_absolute_error: 10.3691
# ... Heartbeat: Reached Epoch 1, Batch 58500. Current loss: 196.0872, MAE: 9.4697 ...
# 58999/77666 ━━━━━━━━━━━━━━━━━━━━ 28:49 93ms/step - loss: 236.4714 - mean_absolute_error: 10.3615
# ... Heartbeat: Reached Epoch 1, Batch 59000. Current loss: 196.3263, MAE: 9.4797 ...
# 59499/77666 ━━━━━━━━━━━━━━━━━━━━ 28:03 93ms/step - loss: 236.1328 - mean_absolute_error: 10.3540
# ... Heartbeat: Reached Epoch 1, Batch 59500. Current loss: 196.1240, MAE: 9.4741 ...
# 59999/77666 ━━━━━━━━━━━━━━━━━━━━ 27:17 93ms/step - loss: 235.7981 - mean_absolute_error: 10.3467
# ... Heartbeat: Reached Epoch 1, Batch 60000. Current loss: 195.7918, MAE: 9.4653 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 60000 ---
# --- Safeguard checkpoint saved successfully. ---
# 60499/77666 ━━━━━━━━━━━━━━━━━━━━ 26:31 93ms/step - loss: 235.4673 - mean_absolute_error: 10.3394
# ... Heartbeat: Reached Epoch 1, Batch 60500. Current loss: 195.6357, MAE: 9.4643 ...
# 60999/77666 ━━━━━━━━━━━━━━━━━━━━ 25:44 93ms/step - loss: 235.1398 - mean_absolute_error: 10.3322
# ... Heartbeat: Reached Epoch 1, Batch 61000. Current loss: 195.3102, MAE: 9.4522 ...
# 61499/77666 ━━━━━━━━━━━━━━━━━━━━ 24:58 93ms/step - loss: 234.8151 - mean_absolute_error: 10.3250
# ... Heartbeat: Reached Epoch 1, Batch 61500. Current loss: 195.0685, MAE: 9.4457 ...
# 61999/77666 ━━━━━━━━━━━━━━━━━━━━ 24:12 93ms/step - loss: 234.4939 - mean_absolute_error: 10.3179
# ... Heartbeat: Reached Epoch 1, Batch 62000. Current loss: 195.0091, MAE: 9.4419 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 62000 ---
# --- Safeguard checkpoint saved successfully. ---
# 62499/77666 ━━━━━━━━━━━━━━━━━━━━ 23:25 93ms/step - loss: 234.1799 - mean_absolute_error: 10.3109
# ... Heartbeat: Reached Epoch 1, Batch 62500. Current loss: 195.4298, MAE: 9.4522 ...
# 62999/77666 ━━━━━━━━━━━━━━━━━━━━ 22:39 93ms/step - loss: 233.8742 - mean_absolute_error: 10.3042
# ... Heartbeat: Reached Epoch 1, Batch 63000. Current loss: 195.8746, MAE: 9.4648 ...
# 63499/77666 ━━━━━━━━━━━━━━━━━━━━ 21:53 93ms/step - loss: 233.5746 - mean_absolute_error: 10.2975
# ... Heartbeat: Reached Epoch 1, Batch 63500. Current loss: 195.8546, MAE: 9.4634 ...
# 63999/77666 ━━━━━━━━━━━━━━━━━━━━ 21:06 93ms/step - loss: 233.2812 - mean_absolute_error: 10.2911
# ... Heartbeat: Reached Epoch 1, Batch 64000. Current loss: 196.0440, MAE: 9.4688 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 64000 ---
# --- Safeguard checkpoint saved successfully. ---
# 64499/77666 ━━━━━━━━━━━━━━━━━━━━ 20:20 93ms/step - loss: 232.9922 - mean_absolute_error: 10.2847
# ... Heartbeat: Reached Epoch 1, Batch 64500. Current loss: 195.8614, MAE: 9.4652 ...
# 64999/77666 ━━━━━━━━━━━━━━━━━━━━ 19:34 93ms/step - loss: 232.7062 - mean_absolute_error: 10.2784
# ... Heartbeat: Reached Epoch 1, Batch 65000. Current loss: 195.8384, MAE: 9.4639 ...
# 65499/77666 ━━━━━━━━━━━━━━━━━━━━ 18:47 93ms/step - loss: 232.4241 - mean_absolute_error: 10.2721
# ... Heartbeat: Reached Epoch 1, Batch 65500. Current loss: 195.8020, MAE: 9.4589 ...
# 65999/77666 ━━━━━━━━━━━━━━━━━━━━ 18:01 93ms/step - loss: 232.1452 - mean_absolute_error: 10.2659
# ... Heartbeat: Reached Epoch 1, Batch 66000. Current loss: 195.5190, MAE: 9.4497 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 66000 ---
# --- Safeguard checkpoint saved successfully. ---
# 66499/77666 ━━━━━━━━━━━━━━━━━━━━ 17:15 93ms/step - loss: 231.8699 - mean_absolute_error: 10.2598
# ... Heartbeat: Reached Epoch 1, Batch 66500. Current loss: 195.4621, MAE: 9.4478 ...
# 66999/77666 ━━━━━━━━━━━━━━━━━━━━ 16:28 93ms/step - loss: 231.5990 - mean_absolute_error: 10.2537
# ... Heartbeat: Reached Epoch 1, Batch 67000. Current loss: 195.5969, MAE: 9.4531 ...
# 67499/77666 ━━━━━━━━━━━━━━━━━━━━ 15:42 93ms/step - loss: 231.3334 - mean_absolute_error: 10.2479
# ... Heartbeat: Reached Epoch 1, Batch 67500. Current loss: 195.7601, MAE: 9.4598 ...
# 67999/77666 ━━━━━━━━━━━━━━━━━━━━ 14:56 93ms/step - loss: 231.0719 - mean_absolute_error: 10.2421
# ... Heartbeat: Reached Epoch 1, Batch 68000. Current loss: 195.6899, MAE: 9.4592 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 68000 ---
# --- Safeguard checkpoint saved successfully. ---
# 68499/77666 ━━━━━━━━━━━━━━━━━━━━ 14:09 93ms/step - loss: 230.8140 - mean_absolute_error: 10.2364
# ... Heartbeat: Reached Epoch 1, Batch 68500. Current loss: 195.7763, MAE: 9.4637 ...
# 68999/77666 ━━━━━━━━━━━━━━━━━━━━ 13:23 93ms/step - loss: 230.5599 - mean_absolute_error: 10.2308
# ... Heartbeat: Reached Epoch 1, Batch 69000. Current loss: 195.6801, MAE: 9.4618 ...
# 69499/77666 ━━━━━━━━━━━━━━━━━━━━ 12:37 93ms/step - loss: 230.3089 - mean_absolute_error: 10.2252
# ... Heartbeat: Reached Epoch 1, Batch 69500. Current loss: 195.5811, MAE: 9.4588 ...
# 69999/77666 ━━━━━━━━━━━━━━━━━━━━ 11:50 93ms/step - loss: 230.0593 - mean_absolute_error: 10.2197
# ... Heartbeat: Reached Epoch 1, Batch 70000. Current loss: 195.1903, MAE: 9.4489 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 70000 ---
# --- Safeguard checkpoint saved successfully. ---
# 70499/77666 ━━━━━━━━━━━━━━━━━━━━ 11:04 93ms/step - loss: 229.8120 - mean_absolute_error: 10.2142
# ... Heartbeat: Reached Epoch 1, Batch 70500. Current loss: 195.0238, MAE: 9.4418 ...
# 70999/77666 ━━━━━━━━━━━━━━━━━━━━ 10:18 93ms/step - loss: 229.5665 - mean_absolute_error: 10.2088
# ... Heartbeat: Reached Epoch 1, Batch 71000. Current loss: 194.8354, MAE: 9.4381 ...
# 71499/77666 ━━━━━━━━━━━━━━━━━━━━ 9:31 93ms/step - loss: 229.3247 - mean_absolute_error: 10.2034
# ... Heartbeat: Reached Epoch 1, Batch 71500. Current loss: 195.1289, MAE: 9.4459 ...
# 71999/77666 ━━━━━━━━━━━━━━━━━━━━ 8:45 93ms/step - loss: 229.0878 - mean_absolute_error: 10.1982
# ... Heartbeat: Reached Epoch 1, Batch 72000. Current loss: 195.3535, MAE: 9.4519 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 72000 ---
# --- Safeguard checkpoint saved successfully. ---
# 72499/77666 ━━━━━━━━━━━━━━━━━━━━ 7:59 93ms/step - loss: 228.8550 - mean_absolute_error: 10.1930
# ... Heartbeat: Reached Epoch 1, Batch 72500. Current loss: 195.3481, MAE: 9.4534 ...
# 72999/77666 ━━━━━━━━━━━━━━━━━━━━ 7:12 93ms/step - loss: 228.6257 - mean_absolute_error: 10.1880
# ... Heartbeat: Reached Epoch 1, Batch 73000. Current loss: 195.2751, MAE: 9.4543 ...
# 73499/77666 ━━━━━━━━━━━━━━━━━━━━ 6:26 93ms/step - loss: 228.3981 - mean_absolute_error: 10.1830
# ... Heartbeat: Reached Epoch 1, Batch 73500. Current loss: 195.0006, MAE: 9.4471 ...
# 73999/77666 ━━━━━━━━━━━━━━━━━━━━ 5:40 93ms/step - loss: 228.1734 - mean_absolute_error: 10.1780
# ... Heartbeat: Reached Epoch 1, Batch 74000. Current loss: 195.2294, MAE: 9.4548 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 74000 ---
# --- Safeguard checkpoint saved successfully. ---
# 74499/77666 ━━━━━━━━━━━━━━━━━━━━ 4:53 93ms/step - loss: 227.9515 - mean_absolute_error: 10.1732
# ... Heartbeat: Reached Epoch 1, Batch 74500. Current loss: 195.0616, MAE: 9.4525 ...
# 74999/77666 ━━━━━━━━━━━━━━━━━━━━ 4:07 93ms/step - loss: 227.7317 - mean_absolute_error: 10.1683
# ... Heartbeat: Reached Epoch 1, Batch 75000. Current loss: 195.0288, MAE: 9.4535 ...
# 75499/77666 ━━━━━━━━━━━━━━━━━━━━ 3:20 93ms/step - loss: 227.5145 - mean_absolute_error: 10.1636
# ... Heartbeat: Reached Epoch 1, Batch 75500. Current loss: 194.9342, MAE: 9.4525 ...
# 75999/77666 ━━━━━━━━━━━━━━━━━━━━ 2:34 93ms/step - loss: 227.2996 - mean_absolute_error: 10.1589
# ... Heartbeat: Reached Epoch 1, Batch 76000. Current loss: 194.8235, MAE: 9.4537 ...
#
# --- Safeguard checkpoint: saving model at epoch 1, batch 76000 ---
# --- Safeguard checkpoint saved successfully. ---
# 76499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:48 93ms/step - loss: 227.0868 - mean_absolute_error: 10.1543
# ... Heartbeat: Reached Epoch 1, Batch 76500. Current loss: 194.6883, MAE: 9.4499 ...
# 76999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:01 93ms/step - loss: 226.8759 - mean_absolute_error: 10.1497
# ... Heartbeat: Reached Epoch 1, Batch 77000. Current loss: 194.6119, MAE: 9.4489 ...
# 77499/77666 ━━━━━━━━━━━━━━━━━━━━ 15s 93ms/step - loss: 226.6665 - mean_absolute_error: 10.1451
# ... Heartbeat: Reached Epoch 1, Batch 77500. Current loss: 194.3111, MAE: 9.4407 ...
# 77666/77666 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 226.5967 - mean_absolute_error: 10.1436
# Epoch 1: val_loss improved from inf to 189.66585, saving model to /kaggle/working/small_transformer_best_model.keras
#
# --- Epoch 1 complete. Updating state file for resumption at Epoch 2. ---
# --- State file updated for next epoch. ---
# 77666/77666 ━━━━━━━━━━━━━━━━━━━━ 7543s 97ms/step - loss: 226.5963 - mean_absolute_error: 10.1436 - val_loss: 189.6658 - val_mean_absolute_error: 9.1430
# Epoch 2/5
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_loss did not improve from 189.66585
#
# --- Epoch 2 complete. Updating state file for resumption at Epoch 3. ---
# --- State file updated for next epoch. ---
# 77666/77666 ━━━━━━━━━━━━━━━━━━━━ 314s 4ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0000e+00 - val_loss: 189.6658 - val_mean_absolute_error: 9.1430
# Epoch 3/5
#   499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:59:59 93ms/step - loss: 191.6489 - mean_absolute_error: 9.3732
# ... Heartbeat: Reached Epoch 3, Batch 500. Current loss: 248.6625, MAE: 10.7168 ...
#   999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:58:58 93ms/step - loss: 207.7152 - mean_absolute_error: 9.6984
# ... Heartbeat: Reached Epoch 3, Batch 1000. Current loss: 220.0594, MAE: 9.8824 ...
#  1499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:58:10 93ms/step - loss: 210.0535 - mean_absolute_error: 9.6871
# ... Heartbeat: Reached Epoch 3, Batch 1500. Current loss: 207.7812, MAE: 9.4282 ...
#  1999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:57:22 93ms/step - loss: 211.0954 - mean_absolute_error: 9.7050
# ... Heartbeat: Reached Epoch 3, Batch 2000. Current loss: 213.8560, MAE: 9.7956 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 2000 ---
# --- Safeguard checkpoint saved successfully. ---
#  2499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:56:37 93ms/step - loss: 211.9115 - mean_absolute_error: 9.7340
# ... Heartbeat: Reached Epoch 3, Batch 2500. Current loss: 213.9507, MAE: 9.8142 ...
#  2999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:55:50 93ms/step - loss: 211.6227 - mean_absolute_error: 9.7279
# ... Heartbeat: Reached Epoch 3, Batch 3000. Current loss: 207.8431, MAE: 9.6314 ...
#  3499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:55:03 93ms/step - loss: 210.7929 - mean_absolute_error: 9.7126
# ... Heartbeat: Reached Epoch 3, Batch 3500. Current loss: 207.6165, MAE: 9.7160 ...
#  3999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:54:15 93ms/step - loss: 210.4606 - mean_absolute_error: 9.7143
# ... Heartbeat: Reached Epoch 3, Batch 4000. Current loss: 208.3465, MAE: 9.7078 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 4000 ---
# --- Safeguard checkpoint saved successfully. ---
#  4499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:53:30 93ms/step - loss: 210.1017 - mean_absolute_error: 9.7091
# ... Heartbeat: Reached Epoch 3, Batch 4500. Current loss: 206.8135, MAE: 9.6403 ...
#  4999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:52:43 93ms/step - loss: 209.5168 - mean_absolute_error: 9.6941
# ... Heartbeat: Reached Epoch 3, Batch 5000. Current loss: 202.8613, MAE: 9.5198 ...
#  5499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:51:56 93ms/step - loss: 208.9430 - mean_absolute_error: 9.6789
# ... Heartbeat: Reached Epoch 3, Batch 5500. Current loss: 204.1551, MAE: 9.5404 ...
#  5999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:51:09 93ms/step - loss: 208.4012 - mean_absolute_error: 9.6657
# ... Heartbeat: Reached Epoch 3, Batch 6000. Current loss: 201.9922, MAE: 9.5204 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 6000 ---
# --- Safeguard checkpoint saved successfully. ---
#  6499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:50:23 93ms/step - loss: 207.7793 - mean_absolute_error: 9.6506
# ... Heartbeat: Reached Epoch 3, Batch 6500. Current loss: 199.1565, MAE: 9.4370 ...
#  6999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:49:36 93ms/step - loss: 207.1996 - mean_absolute_error: 9.6357
# ... Heartbeat: Reached Epoch 3, Batch 7000. Current loss: 199.2383, MAE: 9.4459 ...
#  7499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:48:50 93ms/step - loss: 206.6358 - mean_absolute_error: 9.6224
# ... Heartbeat: Reached Epoch 3, Batch 7500. Current loss: 198.8637, MAE: 9.4490 ...
#  7999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:48:04 93ms/step - loss: 206.0292 - mean_absolute_error: 9.6080
# ... Heartbeat: Reached Epoch 3, Batch 8000. Current loss: 195.9875, MAE: 9.3596 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 8000 ---
# --- Safeguard checkpoint saved successfully. ---
#  8499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:47:18 93ms/step - loss: 205.3849 - mean_absolute_error: 9.5934
# ... Heartbeat: Reached Epoch 3, Batch 8500. Current loss: 193.7495, MAE: 9.3204 ...
#  8999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:46:31 93ms/step - loss: 204.6983 - mean_absolute_error: 9.5759
# ... Heartbeat: Reached Epoch 3, Batch 9000. Current loss: 192.8670, MAE: 9.2715 ...
#  9499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:45:44 93ms/step - loss: 204.1049 - mean_absolute_error: 9.5617
# ... Heartbeat: Reached Epoch 3, Batch 9500. Current loss: 193.5979, MAE: 9.3192 ...
#  9999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:44:58 93ms/step - loss: 203.5513 - mean_absolute_error: 9.5487
# ... Heartbeat: Reached Epoch 3, Batch 10000. Current loss: 192.1444, MAE: 9.2855 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 10000 ---
# --- Safeguard checkpoint saved successfully. ---
# 10499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:44:11 93ms/step - loss: 203.0077 - mean_absolute_error: 9.5360
# ... Heartbeat: Reached Epoch 3, Batch 10500. Current loss: 191.4965, MAE: 9.2734 ...
# 10999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:43:25 93ms/step - loss: 202.4797 - mean_absolute_error: 9.5241
# ... Heartbeat: Reached Epoch 3, Batch 11000. Current loss: 192.4081, MAE: 9.2958 ...
# 11499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:42:38 93ms/step - loss: 202.0525 - mean_absolute_error: 9.5149
# ... Heartbeat: Reached Epoch 3, Batch 11500. Current loss: 192.6570, MAE: 9.3118 ...
# 11999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:41:51 93ms/step - loss: 201.6787 - mean_absolute_error: 9.5073
# ... Heartbeat: Reached Epoch 3, Batch 12000. Current loss: 193.5944, MAE: 9.3606 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 12000 ---
# --- Safeguard checkpoint saved successfully. ---
# 12499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:41:05 93ms/step - loss: 201.3427 - mean_absolute_error: 9.5008
# ... Heartbeat: Reached Epoch 3, Batch 12500. Current loss: 192.5718, MAE: 9.3239 ...
# 12999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:40:19 93ms/step - loss: 201.0164 - mean_absolute_error: 9.4942
# ... Heartbeat: Reached Epoch 3, Batch 13000. Current loss: 193.3578, MAE: 9.3444 ...
# 13499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:39:32 93ms/step - loss: 200.7622 - mean_absolute_error: 9.4900
# ... Heartbeat: Reached Epoch 3, Batch 13500. Current loss: 194.7234, MAE: 9.4107 ...
# 13999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:38:45 93ms/step - loss: 200.5348 - mean_absolute_error: 9.4871
# ... Heartbeat: Reached Epoch 3, Batch 14000. Current loss: 194.4646, MAE: 9.4122 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 14000 ---
# --- Safeguard checkpoint saved successfully. ---
# 14499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:37:59 93ms/step - loss: 200.3274 - mean_absolute_error: 9.4847
# ... Heartbeat: Reached Epoch 3, Batch 14500. Current loss: 194.3572, MAE: 9.4032 ...
# 14999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:37:12 93ms/step - loss: 200.1117 - mean_absolute_error: 9.4817
# ... Heartbeat: Reached Epoch 3, Batch 15000. Current loss: 193.4184, MAE: 9.3853 ...
# 15499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:36:26 93ms/step - loss: 199.8825 - mean_absolute_error: 9.4783
# ... Heartbeat: Reached Epoch 3, Batch 15500. Current loss: 192.3334, MAE: 9.3557 ...
# 15999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:35:39 93ms/step - loss: 199.6331 - mean_absolute_error: 9.4742
# ... Heartbeat: Reached Epoch 3, Batch 16000. Current loss: 191.2755, MAE: 9.3307 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 16000 ---
# --- Safeguard checkpoint saved successfully. ---
# 16499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:34:53 93ms/step - loss: 199.3741 - mean_absolute_error: 9.4698
# ... Heartbeat: Reached Epoch 3, Batch 16500. Current loss: 190.5502, MAE: 9.3123 ...
# 16999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:34:07 93ms/step - loss: 199.1202 - mean_absolute_error: 9.4654
# ... Heartbeat: Reached Epoch 3, Batch 17000. Current loss: 191.1204, MAE: 9.3328 ...
# 17499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:33:20 93ms/step - loss: 198.8644 - mean_absolute_error: 9.4607
# ... Heartbeat: Reached Epoch 3, Batch 17500. Current loss: 189.7808, MAE: 9.2897 ...
# 17999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:32:33 93ms/step - loss: 198.6107 - mean_absolute_error: 9.4557
# ... Heartbeat: Reached Epoch 3, Batch 18000. Current loss: 190.8493, MAE: 9.3029 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 18000 ---
# --- Safeguard checkpoint saved successfully. ---
# 18499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:31:47 93ms/step - loss: 198.3857 - mean_absolute_error: 9.4514
# ... Heartbeat: Reached Epoch 3, Batch 18500. Current loss: 189.7691, MAE: 9.2785 ...
# 18999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:31:01 93ms/step - loss: 198.1483 - mean_absolute_error: 9.4465
# ... Heartbeat: Reached Epoch 3, Batch 19000. Current loss: 188.8533, MAE: 9.2503 ...
# 19499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:30:14 93ms/step - loss: 197.8890 - mean_absolute_error: 9.4407
# ... Heartbeat: Reached Epoch 3, Batch 19500. Current loss: 187.8051, MAE: 9.2143 ...
# 19999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:29:27 93ms/step - loss: 197.6355 - mean_absolute_error: 9.4351
# ... Heartbeat: Reached Epoch 3, Batch 20000. Current loss: 187.5392, MAE: 9.2091 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 20000 ---
# --- Safeguard checkpoint saved successfully. ---
# 20499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:28:41 93ms/step - loss: 197.3871 - mean_absolute_error: 9.4296
# ... Heartbeat: Reached Epoch 3, Batch 20500. Current loss: 187.0416, MAE: 9.2020 ...
# 20999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:27:54 93ms/step - loss: 197.1612 - mean_absolute_error: 9.4248
# ... Heartbeat: Reached Epoch 3, Batch 21000. Current loss: 188.7661, MAE: 9.2604 ...
# 21499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:27:07 93ms/step - loss: 196.9579 - mean_absolute_error: 9.4207
# ... Heartbeat: Reached Epoch 3, Batch 21500. Current loss: 188.0999, MAE: 9.2347 ...
# 21999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:26:21 93ms/step - loss: 196.7524 - mean_absolute_error: 9.4164
# ... Heartbeat: Reached Epoch 3, Batch 22000. Current loss: 187.6261, MAE: 9.2263 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 22000 ---
# --- Safeguard checkpoint saved successfully. ---
# 22499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:25:34 93ms/step - loss: 196.5429 - mean_absolute_error: 9.4121
# ... Heartbeat: Reached Epoch 3, Batch 22500. Current loss: 187.0435, MAE: 9.2117 ...
# 22999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:24:48 93ms/step - loss: 196.3341 - mean_absolute_error: 9.4078
# ... Heartbeat: Reached Epoch 3, Batch 23000. Current loss: 186.8416, MAE: 9.2138 ...
# 23499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:24:01 93ms/step - loss: 196.1249 - mean_absolute_error: 9.4033
# ... Heartbeat: Reached Epoch 3, Batch 23500. Current loss: 186.2944, MAE: 9.1914 ...
# 23999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:23:14 93ms/step - loss: 195.9266 - mean_absolute_error: 9.3991
# ... Heartbeat: Reached Epoch 3, Batch 24000. Current loss: 186.7682, MAE: 9.2020 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 24000 ---
# --- Safeguard checkpoint saved successfully. ---
# ...
# 40999/77666 ━━━━━━━━━━━━━━━━━━━━ 56:51 93ms/step - loss: 192.0938 - mean_absolute_error: 9.3215
# ... Heartbeat: Reached Epoch 3, Batch 41000. Current loss: 185.0028, MAE: 9.1827 ...
# 41499/77666 ━━━━━━━━━━━━━━━━━━━━ 56:05 93ms/step - loss: 192.0064 - mean_absolute_error: 9.3198
# ... Heartbeat: Reached Epoch 3, Batch 41500. Current loss: 184.8239, MAE: 9.1819 ...
# 41999/77666 ━━━━━━━━━━━━━━━━━━━━ 55:18 93ms/step - loss: 191.9240 - mean_absolute_error: 9.3183
# ... Heartbeat: Reached Epoch 3, Batch 42000. Current loss: 185.0199, MAE: 9.1881 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 42000 ---
# --- Safeguard checkpoint saved successfully. ---
# 42499/77666 ━━━━━━━━━━━━━━━━━━━━ 54:32 93ms/step - loss: 191.8421 - mean_absolute_error: 9.3167
# ... Heartbeat: Reached Epoch 3, Batch 42500. Current loss: 185.0596, MAE: 9.1888 ...
# 42999/77666 ━━━━━━━━━━━━━━━━━━━━ 53:45 93ms/step - loss: 191.7663 - mean_absolute_error: 9.3154
# ... Heartbeat: Reached Epoch 3, Batch 43000. Current loss: 185.2417, MAE: 9.2018 ...
# 43499/77666 ━━━━━━━━━━━━━━━━━━━━ 52:58 93ms/step - loss: 191.6896 - mean_absolute_error: 9.3141
# ... Heartbeat: Reached Epoch 3, Batch 43500. Current loss: 184.8315, MAE: 9.1954 ...
# 43999/77666 ━━━━━━━━━━━━━━━━━━━━ 52:12 93ms/step - loss: 191.6072 - mean_absolute_error: 9.3126
# ... Heartbeat: Reached Epoch 3, Batch 44000. Current loss: 184.2517, MAE: 9.1801 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 44000 ---
# --- Safeguard checkpoint saved successfully. ---
# 44499/77666 ━━━━━━━━━━━━━━━━━━━━ 51:25 93ms/step - loss: 191.5263 - mean_absolute_error: 9.3112
# ... Heartbeat: Reached Epoch 3, Batch 44500. Current loss: 184.4432, MAE: 9.1855 ...
# 44999/77666 ━━━━━━━━━━━━━━━━━━━━ 50:39 93ms/step - loss: 191.4460 - mean_absolute_error: 9.3097
# ... Heartbeat: Reached Epoch 3, Batch 45000. Current loss: 184.1470, MAE: 9.1665 ...
# 45499/77666 ━━━━━━━━━━━━━━━━━━━━ 49:52 93ms/step - loss: 191.3658 - mean_absolute_error: 9.3081
# ... Heartbeat: Reached Epoch 3, Batch 45500. Current loss: 184.2724, MAE: 9.1721 ...
# 45999/77666 ━━━━━━━━━━━━━━━━━━━━ 49:05 93ms/step - loss: 191.2882 - mean_absolute_error: 9.3066
# ... Heartbeat: Reached Epoch 3, Batch 46000. Current loss: 184.0924, MAE: 9.1624 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 46000 ---
# --- Safeguard checkpoint saved successfully. ---
# 46499/77666 ━━━━━━━━━━━━━━━━━━━━ 48:19 93ms/step - loss: 191.2094 - mean_absolute_error: 9.3050
# ... Heartbeat: Reached Epoch 3, Batch 46500. Current loss: 183.8365, MAE: 9.1551 ...
# 46999/77666 ━━━━━━━━━━━━━━━━━━━━ 47:32 93ms/step - loss: 191.1309 - mean_absolute_error: 9.3034
# ... Heartbeat: Reached Epoch 3, Batch 47000. Current loss: 183.7146, MAE: 9.1523 ...
# 47499/77666 ━━━━━━━━━━━━━━━━━━━━ 46:46 93ms/step - loss: 191.0529 - mean_absolute_error: 9.3018
# ... Heartbeat: Reached Epoch 3, Batch 47500. Current loss: 183.6986, MAE: 9.1534 ...
# 47999/77666 ━━━━━━━━━━━━━━━━━━━━ 45:59 93ms/step - loss: 190.9744 - mean_absolute_error: 9.3003
# ... Heartbeat: Reached Epoch 3, Batch 48000. Current loss: 183.2936, MAE: 9.1438 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 48000 ---
# --- Safeguard checkpoint saved successfully. ---
# 48499/77666 ━━━━━━━━━━━━━━━━━━━━ 45:13 93ms/step - loss: 190.8943 - mean_absolute_error: 9.2986
# ... Heartbeat: Reached Epoch 3, Batch 48500. Current loss: 183.2371, MAE: 9.1452 ...
# 48999/77666 ━━━━━━━━━━━━━━━━━━━━ 44:26 93ms/step - loss: 190.8162 - mean_absolute_error: 9.2971
# ... Heartbeat: Reached Epoch 3, Batch 49000. Current loss: 183.1734, MAE: 9.1441 ...
# 49499/77666 ━━━━━━━━━━━━━━━━━━━━ 43:40 93ms/step - loss: 190.7376 - mean_absolute_error: 9.2955
# ... Heartbeat: Reached Epoch 3, Batch 49500. Current loss: 183.0411, MAE: 9.1390 ...
# 49999/77666 ━━━━━━━━━━━━━━━━━━━━ 42:53 93ms/step - loss: 190.6613 - mean_absolute_error: 9.2939
# ... Heartbeat: Reached Epoch 3, Batch 50000. Current loss: 182.9881, MAE: 9.1339 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 50000 ---
# --- Safeguard checkpoint saved successfully. ---
# 50499/77666 ━━━━━━━━━━━━━━━━━━━━ 42:06 93ms/step - loss: 190.5865 - mean_absolute_error: 9.2924
# ... Heartbeat: Reached Epoch 3, Batch 50500. Current loss: 183.0781, MAE: 9.1363 ...
# 50999/77666 ━━━━━━━━━━━━━━━━━━━━ 41:20 93ms/step - loss: 190.5118 - mean_absolute_error: 9.2908
# ... Heartbeat: Reached Epoch 3, Batch 51000. Current loss: 182.7664, MAE: 9.1253 ...
# 51499/77666 ━━━━━━━━━━━━━━━━━━━━ 40:33 93ms/step - loss: 190.4379 - mean_absolute_error: 9.2892
# ... Heartbeat: Reached Epoch 3, Batch 51500. Current loss: 182.6540, MAE: 9.1190 ...
# 51999/77666 ━━━━━━━━━━━━━━━━━━━━ 39:47 93ms/step - loss: 190.3610 - mean_absolute_error: 9.2875
# ... Heartbeat: Reached Epoch 3, Batch 52000. Current loss: 182.2513, MAE: 9.1073 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 52000 ---
# --- Safeguard checkpoint saved successfully. ---
# 52499/77666 ━━━━━━━━━━━━━━━━━━━━ 39:00 93ms/step - loss: 190.2821 - mean_absolute_error: 9.2858
# ... Heartbeat: Reached Epoch 3, Batch 52500. Current loss: 182.1383, MAE: 9.1034 ...
# 52999/77666 ━━━━━━━━━━━━━━━━━━━━ 38:14 93ms/step - loss: 190.2080 - mean_absolute_error: 9.2841
# ... Heartbeat: Reached Epoch 3, Batch 53000. Current loss: 182.7097, MAE: 9.1212 ...
# 53499/77666 ━━━━━━━━━━━━━━━━━━━━ 37:27 93ms/step - loss: 190.1389 - mean_absolute_error: 9.2826
# ... Heartbeat: Reached Epoch 3, Batch 53500. Current loss: 182.8509, MAE: 9.1252 ...
# 53999/77666 ━━━━━━━━━━━━━━━━━━━━ 36:40 93ms/step - loss: 190.0702 - mean_absolute_error: 9.2811
# ... Heartbeat: Reached Epoch 3, Batch 54000. Current loss: 182.5101, MAE: 9.1130 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 54000 ---
# --- Safeguard checkpoint saved successfully. ---
# 54499/77666 ━━━━━━━━━━━━━━━━━━━━ 35:54 93ms/step - loss: 190.0010 - mean_absolute_error: 9.2796
# ... Heartbeat: Reached Epoch 3, Batch 54500. Current loss: 182.6127, MAE: 9.1115 ...
# 54999/77666 ━━━━━━━━━━━━━━━━━━━━ 35:07 93ms/step - loss: 189.9325 - mean_absolute_error: 9.2780
# ... Heartbeat: Reached Epoch 3, Batch 55000. Current loss: 182.5090, MAE: 9.1100 ...
# 55499/77666 ━━━━━━━━━━━━━━━━━━━━ 34:21 93ms/step - loss: 189.8635 - mean_absolute_error: 9.2764
# ... Heartbeat: Reached Epoch 3, Batch 55500. Current loss: 182.0951, MAE: 9.0962 ...
# 55999/77666 ━━━━━━━━━━━━━━━━━━━━ 33:34 93ms/step - loss: 189.7940 - mean_absolute_error: 9.2748
# ... Heartbeat: Reached Epoch 3, Batch 56000. Current loss: 182.0281, MAE: 9.0922 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 56000 ---
# --- Safeguard checkpoint saved successfully. ---
# 56499/77666 ━━━━━━━━━━━━━━━━━━━━ 32:48 93ms/step - loss: 189.7233 - mean_absolute_error: 9.2731
# ... Heartbeat: Reached Epoch 3, Batch 56500. Current loss: 181.5796, MAE: 9.0817 ...
# 56999/77666 ━━━━━━━━━━━━━━━━━━━━ 32:01 93ms/step - loss: 189.6525 - mean_absolute_error: 9.2715
# ... Heartbeat: Reached Epoch 3, Batch 57000. Current loss: 181.8547, MAE: 9.0904 ...
# 57499/77666 ━━━━━━━━━━━━━━━━━━━━ 31:15 93ms/step - loss: 189.5839 - mean_absolute_error: 9.2699
# ... Heartbeat: Reached Epoch 3, Batch 57500. Current loss: 181.8755, MAE: 9.0891 ...
# 57999/77666 ━━━━━━━━━━━━━━━━━━━━ 30:28 93ms/step - loss: 189.5182 - mean_absolute_error: 9.2684
# ... Heartbeat: Reached Epoch 3, Batch 58000. Current loss: 182.2973, MAE: 9.1109 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 58000 ---
# --- Safeguard checkpoint saved successfully. ---
# 58499/77666 ━━━━━━━━━━━━━━━━━━━━ 29:42 93ms/step - loss: 189.4568 - mean_absolute_error: 9.2671
# ... Heartbeat: Reached Epoch 3, Batch 58500. Current loss: 182.4360, MAE: 9.1206 ...
# 58999/77666 ━━━━━━━━━━━━━━━━━━━━ 28:55 93ms/step - loss: 189.3983 - mean_absolute_error: 9.2659
# ... Heartbeat: Reached Epoch 3, Batch 59000. Current loss: 182.8267, MAE: 9.1356 ...
# 59499/77666 ━━━━━━━━━━━━━━━━━━━━ 28:09 93ms/step - loss: 189.3423 - mean_absolute_error: 9.2648
# ... Heartbeat: Reached Epoch 3, Batch 59500. Current loss: 182.6976, MAE: 9.1321 ...
# 59999/77666 ━━━━━━━━━━━━━━━━━━━━ 27:22 93ms/step - loss: 189.2859 - mean_absolute_error: 9.2636
# ... Heartbeat: Reached Epoch 3, Batch 60000. Current loss: 182.4317, MAE: 9.1241 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 60000 ---
# --- Safeguard checkpoint saved successfully. ---
# 60499/77666 ━━━━━━━━━━━━━━━━━━━━ 26:36 93ms/step - loss: 189.2290 - mean_absolute_error: 9.2625
# ... Heartbeat: Reached Epoch 3, Batch 60500. Current loss: 182.2872, MAE: 9.1231 ...
# 60999/77666 ━━━━━━━━━━━━━━━━━━━━ 25:49 93ms/step - loss: 189.1712 - mean_absolute_error: 9.2613
# ... Heartbeat: Reached Epoch 3, Batch 61000. Current loss: 181.9971, MAE: 9.1115 ...
# 61499/77666 ━━━━━━━━━━━━━━━━━━━━ 25:03 93ms/step - loss: 189.1122 - mean_absolute_error: 9.2601
# ... Heartbeat: Reached Epoch 3, Batch 61500. Current loss: 181.8242, MAE: 9.1071 ...
# 61999/77666 ━━━━━━━━━━━━━━━━━━━━ 24:16 93ms/step - loss: 189.0533 - mean_absolute_error: 9.2588
# ... Heartbeat: Reached Epoch 3, Batch 62000. Current loss: 181.8891, MAE: 9.1060 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 62000 ---
# --- Safeguard checkpoint saved successfully. ---
# 62499/77666 ━━━━━━━━━━━━━━━━━━━━ 23:30 93ms/step - loss: 188.9981 - mean_absolute_error: 9.2577
# ... Heartbeat: Reached Epoch 3, Batch 62500. Current loss: 182.3504, MAE: 9.1178 ...
# 62999/77666 ━━━━━━━━━━━━━━━━━━━━ 22:43 93ms/step - loss: 188.9475 - mean_absolute_error: 9.2566
# ... Heartbeat: Reached Epoch 3, Batch 63000. Current loss: 182.8684, MAE: 9.1319 ...
# 63499/77666 ━━━━━━━━━━━━━━━━━━━━ 21:57 93ms/step - loss: 188.8997 - mean_absolute_error: 9.2556
# ... Heartbeat: Reached Epoch 3, Batch 63500. Current loss: 182.9218, MAE: 9.1328 ...
# 63999/77666 ━━━━━━━━━━━━━━━━━━━━ 21:10 93ms/step - loss: 188.8544 - mean_absolute_error: 9.2547
# ... Heartbeat: Reached Epoch 3, Batch 64000. Current loss: 183.1716, MAE: 9.1400 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 64000 ---
# --- Safeguard checkpoint saved successfully. ---
# 64499/77666 ━━━━━━━━━━━━━━━━━━━━ 20:24 93ms/step - loss: 188.8101 - mean_absolute_error: 9.2538
# ... Heartbeat: Reached Epoch 3, Batch 64500. Current loss: 182.9961, MAE: 9.1371 ...
# 64999/77666 ━━━━━━━━━━━━━━━━━━━━ 19:37 93ms/step - loss: 188.7655 - mean_absolute_error: 9.2529
# ... Heartbeat: Reached Epoch 3, Batch 65000. Current loss: 183.0975, MAE: 9.1368 ...
# 65499/77666 ━━━━━━━━━━━━━━━━━━━━ 18:51 93ms/step - loss: 188.7219 - mean_absolute_error: 9.2520
# ... Heartbeat: Reached Epoch 3, Batch 65500. Current loss: 183.1497, MAE: 9.1338 ...
# 65999/77666 ━━━━━━━━━━━━━━━━━━━━ 18:04 93ms/step - loss: 188.6785 - mean_absolute_error: 9.2511
# ... Heartbeat: Reached Epoch 3, Batch 66000. Current loss: 182.9003, MAE: 9.1251 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 66000 ---
# --- Safeguard checkpoint saved successfully. ---
# 66499/77666 ━━━━━━━━━━━━━━━━━━━━ 17:18 93ms/step - loss: 188.6356 - mean_absolute_error: 9.2501
# ... Heartbeat: Reached Epoch 3, Batch 66500. Current loss: 182.9406, MAE: 9.1251 ...
# 66999/77666 ━━━━━━━━━━━━━━━━━━━━ 16:31 93ms/step - loss: 188.5941 - mean_absolute_error: 9.2492
# ... Heartbeat: Reached Epoch 3, Batch 67000. Current loss: 183.1204, MAE: 9.1307 ...
# 67499/77666 ━━━━━━━━━━━━━━━━━━━━ 15:45 93ms/step - loss: 188.5546 - mean_absolute_error: 9.2484
# ... Heartbeat: Reached Epoch 3, Batch 67500. Current loss: 183.2885, MAE: 9.1372 ...
# 67999/77666 ━━━━━━━━━━━━━━━━━━━━ 14:58 93ms/step - loss: 188.5163 - mean_absolute_error: 9.2476
# ... Heartbeat: Reached Epoch 3, Batch 68000. Current loss: 183.2899, MAE: 9.1379 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 68000 ---
# --- Safeguard checkpoint saved successfully. ---
# 68499/77666 ━━━━━━━━━━━━━━━━━━━━ 14:12 93ms/step - loss: 188.4787 - mean_absolute_error: 9.2468
# ... Heartbeat: Reached Epoch 3, Batch 68500. Current loss: 183.4410, MAE: 9.1432 ...
# 68999/77666 ━━━━━━━━━━━━━━━━━━━━ 13:25 93ms/step - loss: 188.4421 - mean_absolute_error: 9.2460
# ... Heartbeat: Reached Epoch 3, Batch 69000. Current loss: 183.3849, MAE: 9.1416 ...
# 69499/77666 ━━━━━━━━━━━━━━━━━━━━ 12:38 93ms/step - loss: 188.4059 - mean_absolute_error: 9.2453
# ... Heartbeat: Reached Epoch 3, Batch 69500. Current loss: 183.3499, MAE: 9.1402 ...
# 69999/77666 ━━━━━━━━━━━━━━━━━━━━ 11:52 93ms/step - loss: 188.3684 - mean_absolute_error: 9.2445
# ... Heartbeat: Reached Epoch 3, Batch 70000. Current loss: 183.0022, MAE: 9.1309 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 70000 ---
# --- Safeguard checkpoint saved successfully. ---
# 70499/77666 ━━━━━━━━━━━━━━━━━━━━ 11:06 93ms/step - loss: 188.3304 - mean_absolute_error: 9.2437
# ... Heartbeat: Reached Epoch 3, Batch 70500. Current loss: 182.8686, MAE: 9.1248 ...
# 70999/77666 ━━━━━━━━━━━━━━━━━━━━ 10:19 93ms/step - loss: 188.2917 - mean_absolute_error: 9.2428
# ... Heartbeat: Reached Epoch 3, Batch 71000. Current loss: 182.7447, MAE: 9.1221 ...
# 71499/77666 ━━━━━━━━━━━━━━━━━━━━ 9:33 93ms/step - loss: 188.2542 - mean_absolute_error: 9.2420
# ... Heartbeat: Reached Epoch 3, Batch 71500. Current loss: 183.0791, MAE: 9.1313 ...
# 71999/77666 ━━━━━━━━━━━━━━━━━━━━ 8:46 93ms/step - loss: 188.2190 - mean_absolute_error: 9.2413
# ... Heartbeat: Reached Epoch 3, Batch 72000. Current loss: 183.3515, MAE: 9.1386 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 72000 ---
# --- Safeguard checkpoint saved successfully. ---
# 72499/77666 ━━━━━━━━━━━━━━━━━━━━ 8:00 93ms/step - loss: 188.1852 - mean_absolute_error: 9.2406
# ... Heartbeat: Reached Epoch 3, Batch 72500. Current loss: 183.3505, MAE: 9.1403 ...
# 72999/77666 ━━━━━━━━━━━━━━━━━━━━ 7:13 93ms/step - loss: 188.1528 - mean_absolute_error: 9.2399
# ... Heartbeat: Reached Epoch 3, Batch 73000. Current loss: 183.3659, MAE: 9.1434 ...
# 73499/77666 ━━━━━━━━━━━━━━━━━━━━ 6:27 93ms/step - loss: 188.1197 - mean_absolute_error: 9.2392
# ... Heartbeat: Reached Epoch 3, Batch 73500. Current loss: 183.1736, MAE: 9.1380 ...
# 73999/77666 ━━━━━━━━━━━━━━━━━━━━ 5:40 93ms/step - loss: 188.0875 - mean_absolute_error: 9.2386
# ... Heartbeat: Reached Epoch 3, Batch 74000. Current loss: 183.4829, MAE: 9.1493 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 74000 ---
# --- Safeguard checkpoint saved successfully. ---
# 74499/77666 ━━━━━━━━━━━━━━━━━━━━ 4:54 93ms/step - loss: 188.0559 - mean_absolute_error: 9.2380
# ... Heartbeat: Reached Epoch 3, Batch 74500. Current loss: 183.3322, MAE: 9.1472 ...
# 74999/77666 ━━━━━━━━━━━━━━━━━━━━ 4:07 93ms/step - loss: 188.0240 - mean_absolute_error: 9.2374
# ... Heartbeat: Reached Epoch 3, Batch 75000. Current loss: 183.3502, MAE: 9.1492 ...
# 75499/77666 ━━━━━━━━━━━━━━━━━━━━ 3:21 93ms/step - loss: 187.9924 - mean_absolute_error: 9.2368
# ... Heartbeat: Reached Epoch 3, Batch 75500. Current loss: 183.2867, MAE: 9.1483 ...
# 75999/77666 ━━━━━━━━━━━━━━━━━━━━ 2:34 93ms/step - loss: 187.9612 - mean_absolute_error: 9.2362
# ... Heartbeat: Reached Epoch 3, Batch 76000. Current loss: 183.2194, MAE: 9.1506 ...
#
# --- Safeguard checkpoint: saving model at epoch 3, batch 76000 ---
# --- Safeguard checkpoint saved successfully. ---
# 76499/77666 ━━━━━━━━━━━━━━━━━━━━ 1:48 93ms/step - loss: 187.9297 - mean_absolute_error: 9.2356
# ... Heartbeat: Reached Epoch 3, Batch 76500. Current loss: 183.1045, MAE: 9.1475 ...
# 76999/77666 ━━━━━━━━━━━━━━━━━━━━ 1:01 93ms/step - loss: 187.8979 - mean_absolute_error: 9.2350
# ... Heartbeat: Reached Epoch 3, Batch 77000. Current loss: 183.0769, MAE: 9.1483 ...
# 77499/77666 ━━━━━━━━━━━━━━━━━━━━ 15s 93ms/step - loss: 187.8657 - mean_absolute_error: 9.2345
# ... Heartbeat: Reached Epoch 3, Batch 77500. Current loss: 182.8144, MAE: 9.1414 ...
# 77666/77666 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 187.8546 - mean_absolute_error: 9.2343
# Epoch 3: val_loss did not improve from 189.66585
#
# --- Epoch 3 complete. Updating state file for resumption at Epoch 4. ---
# --- State file updated for next epoch. ---
# 77666/77666 ━━━━━━━━━━━━━━━━━━━━ 7528s 97ms/step - loss: 187.8546 - mean_absolute_error: 9.2343 - val_loss: 207.0581 - val_mean_absolute_error: 9.8946
# Epoch 3: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %% [markdown]
# Cell 8: Evaluation

# %%
from sklearn.metrics import r2_score

print("\n--- Evaluating Final Model Performance ---")

# load best model
print(f"--- Loading best model from {MODEL_SAVE_PATH} ---")
loaded_model = keras.models.load_model(
    MODEL_SAVE_PATH,
    custom_objects={"TransformerBlock": TransformerBlock}
)

# make predictions on validation set
print("--- Generating predictions on validation set... ---")
y_pred = loaded_model.predict(val_dataset)

print("--- Extracting true labels for comparison... ---")
y_true = np.concatenate([y for x, y in val_dataset], axis=0)

y_pred = y_pred[:len(y_true)]

final_mae = np.mean(np.abs(y_true - y_pred.squeeze()))
final_mse = np.mean((y_true - y_pred.squeeze())**2)
final_r2 = r2_score(y_true, y_pred)

print("\n--- Final Model Evaluation on Validation Set ---")
print(f"  Mean Absolute Error (MAE): {final_mae:.4f}")
print(f"  Mean Squared Error (MSE):  {final_mse:.4f}")
print(f"  R-squared (R²):            {final_r2:.4f}")
print("-------------------------------------------------")

# plot training history
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss'); plt.ylabel('Loss (MSE)'); plt.xlabel('Epoch')
plt.legend(); plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['mean_absolute_error'], label='Training MAE')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.title('Model MAE'); plt.ylabel('MAE'); plt.xlabel('Epoch')
plt.legend(); plt.grid(True)
plt.tight_layout(); plt.show()

# plot predictions vs actual
plt.figure(figsize=(10, 6))
sample_size = min(1000, len(y_true))
plt.scatter(y_true[:sample_size], y_pred[:sample_size], alpha=0.3, label='Predictions')
plt.plot([min(y_true), max(y_true)], [min(y_true), max(y_true)], 'r--', lw=2, label='Perfect Fit')
plt.title('Prediction vs. Actual Values (Sample)'); plt.xlabel('Actual BIS'); plt.ylabel('Predicted BIS')
plt.legend(); plt.grid(True)
plt.show()
# Out:
# --- Evaluating Final Model Performance ---
# --- Loading best model from /kaggle/working/small_transformer_best_model.keras ---
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:393: UserWarning: `build()` was called on layer 'transformer_block', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:393: UserWarning: `build()` was called on layer 'transformer_block_1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'loss_scale_optimizer', because it has 81 variables whereas the saved optimizer has 77 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adamw', because it has 77 variables whereas the saved optimizer has 0 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# --- Generating predictions on validation set... ---
# 8313/8313 ━━━━━━━━━━━━━━━━━━━━ 244s 29ms/step
# --- Extracting true labels for comparison... ---
#
# --- Final Model Evaluation on Validation Set ---
#   Mean Absolute Error (MAE): 9.1429
#   Mean Squared Error (MSE):  189.6676
#   R-squared (R²):            0.1929
# -------------------------------------------------
